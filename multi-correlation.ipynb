# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
states = pd.read_excel('aspe-uninsured-estimates-by-state.xlsx', sheet_name='All Uninsured (%)')
states = states.drop([51])
states = states.replace('**', 0)
states
# Out:
#               State Name  \
# 0                Alabama
# 1                 Alaska
# 2                Arizona
# 3               Arkansas
# 4             California
# 5               Colorado
# 6            Connecticut
# 7               Delaware
# 8   District of Columbia
# 9                Florida
# 10               Georgia
# 11                Hawaii
# 12                 Idaho
# 13              Illinois
# 14               Indiana
# 15                  Iowa
# 16                Kansas
# 17              Kentucky
# 18             Louisiana
# 19                 Maine
# 20              Maryland
# 21         Massachusetts
# 22              Michigan
# 23             Minnesota
# 24           Mississippi
# 25              Missouri
# 26               Montana
# 27              Nebraska
# 28                Nevada
# 29         New Hampshire
# 30            New Jersey
# 31            New Mexico
# 32              New York
# 33        North Carolina
# 34          North Dakota
# 35                  Ohio
# 36              Oklahoma
# 37                Oregon
# 38          Pennsylvania
# 39          Rhode Island
# 40        South Carolina
# 41          South Dakota
# 42             Tennessee
# 43                 Texas
# 44                  Utah
# 45               Vermont
# 46              Virginia
# 47            Washington
# 48         West Virginia
# 49             Wisconsin
# 50               Wyoming
#
#     Total Non-Elderly Population (Excluding Undocumented)  \
# 0                                             3986500
# 1                                              629300
# 2                                             5720700
# 3                                             2443900
# 4                                            32060700
# 5                                             4758400
# 6                                             2795000
# 7                                              757200
# 8                                              601300
# 9                                            16240100
# 10                                            8745400
# 11                                            1103200
# 12                                            1470500
# 13                                           10228500
# 14                                            5554800
# 15                                            2559500
# 16                                            2366200
# 17                                            3658600
# 18                                            3842400
# 19                                            1051600
# 20                                            4831300
# 21                                            5513800
# 22                                            8112200
# 23                                            4619700
# 24                                            2466600
# 25                                            5019500
# 26                                             857500
# 27                                            1567000
# 28                                            2406400
# 29                                            1093100
# 30                                            6989800
# 31                                            1662600
# 32                                           15699900
# 33                                            8418000
# 34                                             637100
# 35                                            9550500
# 36                                            3248200
# 37                                            3343300
# 38                                           10221800
# 39                                             843800
# 40                                            4117300
# 41                                             722600
# 42                                            5554900
# 43                                           23953300
# 44                                            2734100
# 45                                             495500
# 46                                            6879500
# 47                                            6126700
# 48                                            1421200
# 49                                            4716500
# 50                                             473800
#
#     Uninsured Population (Excluding Undocumented)  Percent Uninsured  \
# 0                                          456100               0.11
# 1                                           80300               0.13
# 2                                          698800               0.12
# 3                                          257200               0.11
# 4                                         2397600               0.07
# 5                                          392300               0.08
# 6                                          142200               0.05
# 7                                           57800               0.08
# 8                                           22100               0.04
# 9                                         2519500               0.16
# 10                                        1268500               0.15
# 11                                          51200               0.05
# 12                                         170900               0.12
# 13                                         751100               0.07
# 14                                         557400               0.10
# 15                                         135800               0.05
# 16                                         235400               0.10
# 17                                         274200               0.07
# 18                                         391700               0.10
# 19                                         106400               0.10
# 20                                         241400               0.05
# 21                                         175800               0.03
# 22                                         561200               0.07
# 23                                         242400               0.05
# 24                                         390700               0.16
# 25                                         607600               0.12
# 26                                          87900               0.10
# 27                                         133800               0.09
# 28                                         275900               0.11
# 29                                          83500               0.08
# 30                                         506900               0.07
# 31                                         172500               0.10
# 32                                         840000               0.05
# 33                                         996400               0.12
# 34                                          53800               0.08
# 35                                         755500               0.08
# 36                                         546500               0.17
# 37                                         259300               0.08
# 38                                         703200               0.07
# 39                                          34700               0.04
# 40                                         499600               0.12
# 41                                          82300               0.11
# 42                                         621800               0.11
# 43                                        4534900               0.19
# 44                                         262500               0.10
# 45                                          25600               0.05
# 46                                         542400               0.08
# 47                                         392400               0.06
# 48                                         123500               0.09
# 49                                         297900               0.06
# 50                                          67900               0.14
#
#     % HIU Income < 100% FPL  % HIU Income 100-138% FPL  \
# 0                      0.47                       0.11
# 1                      0.26                       0.10
# 2                      0.32                       0.09
# 3                      0.34                       0.11
# 4                      0.30                       0.08
# 5                      0.23                       0.07
# 6                      0.22                       0.07
# 7                      0.32                       0.07
# 8                      0.41                       0.07
# 9                      0.35                       0.09
# 10                     0.41                       0.10
# 11                     0.41                       0.07
# 12                     0.30                       0.11
# 13                     0.30                       0.09
# 14                     0.30                       0.11
# 15                     0.27                       0.08
# 16                     0.33                       0.12
# 17                     0.32                       0.10
# 18                     0.38                       0.07
# 19                     0.23                       0.10
# 20                     0.31                       0.07
# 21                     0.27                       0.07
# 22                     0.31                       0.10
# 23                     0.21                       0.09
# 24                     0.49                       0.10
# 25                     0.39                       0.11
# 26                     0.24                       0.06
# 27                     0.33                       0.09
# 28                     0.29                       0.09
# 29                     0.20                       0.07
# 30                     0.27                       0.10
# 31                     0.35                       0.11
# 32                     0.30                       0.07
# 33                     0.36                       0.10
# 34                     0.23                       0.08
# 35                     0.29                       0.09
# 36                     0.41                       0.09
# 37                     0.25                       0.08
# 38                     0.33                       0.09
# 39                     0.21                       0.04
# 40                     0.40                       0.10
# 41                     0.32                       0.12
# 42                     0.40                       0.10
# 43                     0.34                       0.11
# 44                     0.30                       0.09
# 45                     0.25                       0.07
# 46                     0.33                       0.08
# 47                     0.23                       0.07
# 48                     0.34                       0.12
# 49                     0.26                       0.12
# 50                     0.23                       0.07
#
#     % HIU Income 139-249% FPL  % HIU Income 250-400% FPL  \
# 0                        0.21                       0.13
# 1                        0.28                       0.22
# 2                        0.28                       0.19
# 3                        0.31                       0.15
# 4                        0.26                       0.19
# 5                        0.26                       0.23
# 6                        0.25                       0.21
# 7                        0.28                       0.18
# 8                        0.20                       0.12
# 9                        0.26                       0.17
# 10                       0.24                       0.14
# 11                       0.20                       0.14
# 12                       0.26                       0.20
# 13                       0.27                       0.17
# 14                       0.29                       0.18
# 15                       0.29                       0.19
# 16                       0.26                       0.16
# 17                       0.29                       0.16
# 18                       0.24                       0.15
# 19                       0.27                       0.25
# 20                       0.22                       0.19
# 21                       0.22                       0.19
# 22                       0.27                       0.19
# 23                       0.24                       0.27
# 24                       0.23                       0.11
# 25                       0.26                       0.14
# 26                       0.26                       0.22
# 27                       0.29                       0.18
# 28                       0.29                       0.18
# 29                       0.28                       0.18
# 30                       0.23                       0.21
# 31                       0.27                       0.15
# 32                       0.23                       0.19
# 33                       0.27                       0.16
# 34                       0.28                       0.16
# 35                       0.31                       0.19
# 36                       0.25                       0.14
# 37                       0.27                       0.20
# 38                       0.25                       0.18
# 39                       0.33                       0.23
# 40                       0.22                       0.15
# 41                       0.28                       0.16
# 42                       0.25                       0.15
# 43                       0.26                       0.16
# 44                       0.29                       0.20
# 45                       0.24                       0.22
# 46                       0.26                       0.18
# 47                       0.27                       0.22
# 48                       0.27                       0.14
# 49                       0.25                       0.20
# 50                       0.31                       0.21
#
#     % HIU Income 400% FPL  % Age 0-18  ...  % College Grad  \
# 0                    0.09        0.08  ...            0.08
# 1                    0.14        0.17  ...            0.13
# 2                    0.13        0.21  ...            0.15
# 3                    0.08        0.15  ...            0.07
# 4                    0.16        0.14  ...            0.17
# 5                    0.21        0.16  ...            0.21
# 6                    0.25        0.15  ...            0.23
# 7                    0.15        0.15  ...            0.19
# 8                    0.20        0.12  ...            0.29
# 9                    0.13        0.12  ...            0.16
# 10                   0.10        0.14  ...            0.13
# 11                   0.18        0.19  ...            0.22
# 12                   0.13        0.13  ...            0.14
# 13                   0.17        0.15  ...            0.18
# 14                   0.12        0.20  ...            0.11
# 15                   0.17        0.14  ...            0.13
# 16                   0.13        0.16  ...            0.13
# 17                   0.13        0.15  ...            0.11
# 18                   0.15        0.12  ...            0.10
# 19                   0.15        0.14  ...            0.15
# 20                   0.21        0.14  ...            0.21
# 21                   0.24        0.11  ...            0.23
# 22                   0.12        0.13  ...            0.13
# 23                   0.18        0.17  ...            0.17
# 24                   0.08        0.11  ...            0.08
# 25                   0.10        0.15  ...            0.11
# 26                   0.21        0.18  ...            0.20
# 27                   0.11        0.18  ...            0.16
# 28                   0.15        0.18  ...            0.15
# 29                   0.27        0.14  ...            0.19
# 30                   0.20        0.15  ...            0.19
# 31                   0.13        0.16  ...            0.14
# 32                   0.21        0.12  ...            0.22
# 33                   0.12        0.12  ...            0.14
# 34                   0.26        0.28  ...            0.20
# 35                   0.12        0.17  ...            0.13
# 36                   0.11        0.14  ...            0.11
# 37                   0.20        0.14  ...            0.17
# 38                   0.16        0.17  ...            0.14
# 39                   0.19        0.10  ...            0.21
# 40                   0.12        0.12  ...            0.12
# 41                   0.11        0.18  ...            0.12
# 42                   0.10        0.12  ...            0.11
# 43                   0.12        0.20  ...            0.13
# 44                   0.13        0.28  ...            0.18
# 45                   0.22        0.06  ...            0.16
# 46                   0.14        0.15  ...            0.18
# 47                   0.20        0.13  ...            0.16
# 48                   0.14        0.12  ...            0.13
# 49                   0.17        0.16  ...            0.13
# 50                   0.19        0.21  ...            0.15
#
#     % No English Speaking Adults in HH  % English Spoken in HH  \
# 0                                 0.02                    0.97
# 1                                 0.01                    0.97
# 2                                 0.07                    0.90
# 3                                 0.04                    0.95
# 4                                 0.14                    0.75
# 5                                 0.07                    0.91
# 6                                 0.10                    0.85
# 7                                 0.05                    0.91
# 8                                 0.03                    0.97
# 9                                 0.11                    0.84
# 10                                0.05                    0.94
# 11                                0.07                    0.89
# 12                                0.05                    0.95
# 13                                0.08                    0.86
# 14                                0.06                    0.93
# 15                                0.04                    0.95
# 16                                0.07                    0.93
# 17                                0.04                    0.95
# 18                                0.03                    0.96
# 19                                0.01                    0.99
# 20                                0.07                    0.89
# 21                                0.07                    0.87
# 22                                0.03                    0.95
# 23                                0.04                    0.93
# 24                                0.02                    0.98
# 25                                0.02                    0.97
# 26                                0.01                    0.99
# 27                                0.08                    0.90
# 28                                0.10                    0.86
# 29                                0.06                    0.92
# 30                                0.17                    0.75
# 31                                0.10                    0.88
# 32                                0.16                    0.76
# 33                                0.05                    0.94
# 34                                0.02                    0.97
# 35                                0.05                    0.93
# 36                                0.03                    0.96
# 37                                0.04                    0.94
# 38                                0.07                    0.89
# 39                                0.08                    0.85
# 40                                0.04                    0.96
# 41                                0.01                    0.98
# 42                                0.04                    0.95
# 43                                0.14                    0.81
# 44                                0.05                    0.93
# 45                                0.00                    0.97
# 46                                0.06                    0.92
# 47                                0.08                    0.87
# 48                                0.01                    0.99
# 49                                0.06                    0.92
# 50                                0.02                    0.98
#
#     % Spanish Spoken in HH  % Chinese Spoken in HH  % Korean Spoken in HH  \
# 0                     0.03                    0.00                   0.00
# 1                     0.01                    0.00                   0.00
# 2                     0.08                    0.00                   0.00
# 3                     0.04                    0.00                   0.00
# 4                     0.19                    0.01                   0.01
# 5                     0.06                    0.00                   0.00
# 6                     0.08                    0.00                   0.00
# 7                     0.04                    0.00                   0.00
# 8                     0.02                    0.00                   0.00
# 9                     0.14                    0.00                   0.00
# 10                    0.05                    0.00                   0.00
# 11                    0.01                    0.01                   0.00
# 12                    0.04                    0.00                   0.00
# 13                    0.10                    0.01                   0.00
# 14                    0.04                    0.00                   0.00
# 15                    0.03                    0.00                   0.00
# 16                    0.05                    0.01                   0.00
# 17                    0.02                    0.00                   0.00
# 18                    0.03                    0.00                   0.00
# 19                    0.00                    0.01                   0.00
# 20                    0.07                    0.01                   0.00
# 21                    0.06                    0.01                   0.00
# 22                    0.02                    0.00                   0.00
# 23                    0.02                    0.00                   0.00
# 24                    0.01                    0.00                   0.00
# 25                    0.01                    0.00                   0.00
# 26                    0.00                    0.00                   0.00
# 27                    0.06                    0.00                   0.00
# 28                    0.12                    0.00                   0.00
# 29                    0.05                    0.01                   0.00
# 30                    0.18                    0.00                   0.01
# 31                    0.10                    0.00                   0.00
# 32                    0.14                    0.03                   0.00
# 33                    0.05                    0.00                   0.00
# 34                    0.01                    0.00                   0.00
# 35                    0.02                    0.00                   0.00
# 36                    0.03                    0.00                   0.00
# 37                    0.05                    0.00                   0.00
# 38                    0.04                    0.01                   0.00
# 39                    0.12                    0.01                   0.00
# 40                    0.04                    0.00                   0.00
# 41                    0.01                    0.00                   0.00
# 42                    0.04                    0.00                   0.00
# 43                    0.17                    0.00                   0.00
# 44                    0.05                    0.00                   0.00
# 45                    0.03                    0.00                   0.00
# 46                    0.05                    0.01                   0.00
# 47                    0.08                    0.01                   0.01
# 48                    0.01                    0.00                   0.00
# 49                    0.04                    0.00                   0.00
# 50                    0.02                    0.00                   0.00
#
#     % Vietnamese Spoken in HH  % Tagalog Spoken in HH  % Russian Spoken in HH  \
# 0                        0.00                    0.00                    0.00
# 1                        0.00                    0.00                    0.00
# 2                        0.00                    0.00                    0.00
# 3                        0.00                    0.00                    0.00
# 4                        0.01                    0.00                    0.00
# 5                        0.00                    0.00                    0.00
# 6                        0.00                    0.00                    0.00
# 7                        0.00                    0.00                    0.00
# 8                        0.00                    0.00                    0.00
# 9                        0.00                    0.00                    0.00
# 10                       0.00                    0.00                    0.00
# 11                       0.00                    0.01                    0.00
# 12                       0.00                    0.00                    0.00
# 13                       0.00                    0.00                    0.00
# 14                       0.00                    0.00                    0.00
# 15                       0.00                    0.00                    0.00
# 16                       0.00                    0.00                    0.00
# 17                       0.00                    0.00                    0.00
# 18                       0.01                    0.00                    0.00
# 19                       0.00                    0.00                    0.00
# 20                       0.00                    0.00                    0.00
# 21                       0.00                    0.00                    0.00
# 22                       0.00                    0.00                    0.00
# 23                       0.00                    0.00                    0.00
# 24                       0.00                    0.00                    0.00
# 25                       0.00                    0.00                    0.00
# 26                       0.00                    0.00                    0.00
# 27                       0.00                    0.00                    0.00
# 28                       0.00                    0.00                    0.00
# 29                       0.00                    0.00                    0.00
# 30                       0.00                    0.00                    0.00
# 31                       0.00                    0.00                    0.00
# 32                       0.00                    0.00                    0.01
# 33                       0.00                    0.00                    0.00
# 34                       0.00                    0.00                    0.00
# 35                       0.00                    0.00                    0.00
# 36                       0.00                    0.00                    0.00
# 37                       0.00                    0.00                    0.00
# 38                       0.00                    0.00                    0.00
# 39                       0.00                    0.00                    0.00
# 40                       0.00                    0.00                    0.00
# 41                       0.00                    0.00                    0.00
# 42                       0.00                    0.00                    0.00
# 43                       0.00                    0.00                    0.00
# 44                       0.00                    0.00                    0.00
# 45                       0.00                    0.00                    0.00
# 46                       0.00                    0.00                    0.00
# 47                       0.01                    0.00                    0.00
# 48                       0.00                    0.00                    0.00
# 49                       0.00                    0.00                    0.00
# 50                       0.00                    0.00                    0.00
#
#     % Other Language Spoken in HH
# 0                            0.00
# 1                            0.02
# 2                            0.02
# 3                            0.01
# 4                            0.02
# 5                            0.02
# 6                            0.06
# 7                            0.03
# 8                            0.00
# 9                            0.02
# 10                           0.01
# 11                           0.08
# 12                           0.00
# 13                           0.03
# 14                           0.03
# 15                           0.01
# 16                           0.02
# 17                           0.02
# 18                           0.01
# 19                           0.00
# 20                           0.03
# 21                           0.06
# 22                           0.03
# 23                           0.04
# 24                           0.00
# 25                           0.01
# 26                           0.00
# 27                           0.03
# 28                           0.01
# 29                           0.02
# 30                           0.06
# 31                           0.02
# 32                           0.05
# 33                           0.01
# 34                           0.02
# 35                           0.05
# 36                           0.01
# 37                           0.01
# 38                           0.06
# 39                           0.02
# 40                           0.00
# 41                           0.00
# 42                           0.01
# 43                           0.01
# 44                           0.01
# 45                           0.00
# 46                           0.02
# 47                           0.02
# 48                           0.00
# 49                           0.03
# 50                           0.00
#
# [51 rows x 47 columns]

# %% [markdown]
# # Run Linear Regression Between Groups and Within Groups

# %%
# grouping variables
income = ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL',
           '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL','% HIU Income 400% FPL']
age = ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
gender = ['% Male', '% Female']
origin = ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino',
          '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander',
          '% American Indian / Alaska Native', '% Multi-racial or Other']
employment = ['% Employed in Agriculture Industry', 
             '% Employed in Mining/Construction Industry','% Employed in Manufacturing Industry', 
             '% Employed in Trade Industry','% Employed in Info/Finance Industry', 
             '% Employed in Education/Health Industry','% Employed in Entertainment Industry',
             '% Employed in Service Industry','% Employed in Military/Public Industry']
education = ['% Less than High School', '% High School Diploma', '% College Grad']
language = ['% No English Speaking Adults in HH', '% English Spoken in HH',
            '% Spanish Spoken in HH', '% Chinese Spoken in HH',
            '% Korean Spoken in HH', '% Vietnamese Spoken in HH',
            '% Tagalog Spoken in HH', '% Russian Spoken in HH',
            '% Other Language Spoken in HH']
new_cols = [income, age, gender, '% Married', '% Child in Family', origin,
          '% SNAP Recipient', '% With a disability','% Full-time Worker in Family',employment, education, 
            language]

# %%
# mutify the function to take in two sets of data and calculate 
# the linear correlation between them
def perform_linear(col1,col2):
    x = states[col1]
    y = states[col2]
    lr = LinearRegression()
    reg = lr.fit(x, y)
    y_pred = lr.predict(x)
    
    r2 = reg.score(x, y)
    rms = np.sqrt(mean_squared_error(y, y_pred))
    print('R^2:', r2)
    print('Root Mean Square:', rms)

# %%
#finding the R^2 and rms between the group of income variables and
#other vairables
for col in new_cols:
    print(col)
    perform_linear(income,col)
# Out:
# ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL', '% HIU Income 400% FPL']
# R^2: 1.0
# Root Mean Square: 4.3756153221168447e-17
# ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
# R^2: 0.13469044609496347
# Root Mean Square: 0.029317173238997695
# ['% Male', '% Female']
# R^2: 0.17392220290156135
# Root Mean Square: 0.031287490089363934
# % Married
# R^2: 0.22091459800922486
# Root Mean Square: 0.030655423471557742
# % Child in Family
# R^2: 0.34192102979646155
# Root Mean Square: 0.049268425206810205
# ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino', '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander', '% American Indian / Alaska Native', '% Multi-racial or Other']
# R^2: 0.17443772583192474
# Root Mean Square: 0.0981294996802577
# % SNAP Recipient
# R^2: 0.481818956273817
# Root Mean Square: 0.03604300701812119
# % With a disability
# R^2: 0.3481270335977521
# Root Mean Square: 0.018111230365931173
# % Full-time Worker in Family
# R^2: 0.8477046623623092
# Root Mean Square: 0.018895866928785966
# ['% Employed in Agriculture Industry', '% Employed in Mining/Construction Industry', '% Employed in Manufacturing Industry', '% Employed in Trade Industry', '% Employed in Info/Finance Industry', '% Employed in Education/Health Industry', '% Employed in Entertainment Industry', '% Employed in Service Industry', '% Employed in Military/Public Industry']
# R^2: 0.1649766676276313
# Root Mean Square: 0.016733892567975858
# ['% Less than High School', '% High School Diploma', '% College Grad']
# R^2: 0.4155046483422593
# Root Mean Square: 0.030152407910571777
# ['% No English Speaking Adults in HH', '% English Spoken in HH', '% Spanish Spoken in HH', '% Chinese Spoken in HH', '% Korean Spoken in HH', '% Vietnamese Spoken in HH', '% Tagalog Spoken in HH', '% Russian Spoken in HH', '% Other Language Spoken in HH']
# R^2: 0.10257044054149488
# Root Mean Square: 0.028022037804668113

# %%
#finding the R^2 and rms between the group of age variables and
#other vairables
for col in new_cols:
    print(col)
    perform_linear(age,col)
# Out:
# ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL', '% HIU Income 400% FPL']
# R^2: 0.14416423704716527
# Root Mean Square: 0.039420694029484
# ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
# R^2: 1.0
# Root Mean Square: 3.3252933287712145e-17
# ['% Male', '% Female']
# R^2: 0.46230935628817843
# Root Mean Square: 0.025242158532606356
# % Married
# R^2: 0.4697386935568507
# Root Mean Square: 0.02529063624145211
# % Child in Family
# R^2: 0.7788212143926594
# Root Mean Square: 0.028562841455759255
# ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino', '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander', '% American Indian / Alaska Native', '% Multi-racial or Other']
# R^2: 0.19009019741100244
# Root Mean Square: 0.1007482846334878
# % SNAP Recipient
# R^2: 0.126988665033118
# Root Mean Square: 0.046783229348381264
# % With a disability
# R^2: 0.04888867627429072
# Root Mean Square: 0.021876716826775187
# % Full-time Worker in Family
# R^2: 0.2558842243880969
# Root Mean Square: 0.041768008995673754
# ['% Employed in Agriculture Industry', '% Employed in Mining/Construction Industry', '% Employed in Manufacturing Industry', '% Employed in Trade Industry', '% Employed in Info/Finance Industry', '% Employed in Education/Health Industry', '% Employed in Entertainment Industry', '% Employed in Service Industry', '% Employed in Military/Public Industry']
# R^2: 0.17594659456324205
# Root Mean Square: 0.016775067856512116
# ['% Less than High School', '% High School Diploma', '% College Grad']
# R^2: 0.18828422659797908
# Root Mean Square: 0.03627029217950364
# ['% No English Speaking Adults in HH', '% English Spoken in HH', '% Spanish Spoken in HH', '% Chinese Spoken in HH', '% Korean Spoken in HH', '% Vietnamese Spoken in HH', '% Tagalog Spoken in HH', '% Russian Spoken in HH', '% Other Language Spoken in HH']
# R^2: 0.04828103778826671
# Root Mean Square: 0.02853913670501485

# %%
#finding the R^2 and rms between the group of gender variables and
#other vairables
for col in new_cols :
    print(col)
    perform_linear(gender,col)
# Out:
# ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL', '% HIU Income 400% FPL']
# R^2: 0.06116250277305082
# Root Mean Square: 0.041363481287104244
# ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
# R^2: 0.14357858648590302
# Root Mean Square: 0.02891808908628674
# ['% Male', '% Female']
# R^2: 1.0
# Root Mean Square: 3.9635269915872887e-17
# % Married
# R^2: 0.4052873347617779
# Root Mean Square: 0.02678356483101098
# % Child in Family
# R^2: 0.4189691753763283
# Root Mean Square: 0.04629448542237025
# ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino', '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander', '% American Indian / Alaska Native', '% Multi-racial or Other']
# R^2: 0.049601492003008806
# Root Mean Square: 0.10741675386869128
# % SNAP Recipient
# R^2: 0.046474926379495574
# Root Mean Square: 0.04889295820647535
# % With a disability
# R^2: 0.09867532073354868
# Root Mean Square: 0.021296444385522428
# % Full-time Worker in Family
# R^2: 0.06153219391578968
# Root Mean Square: 0.04690651929042799
# ['% Employed in Agriculture Industry', '% Employed in Mining/Construction Industry', '% Employed in Manufacturing Industry', '% Employed in Trade Industry', '% Employed in Info/Finance Industry', '% Employed in Education/Health Industry', '% Employed in Entertainment Industry', '% Employed in Service Industry', '% Employed in Military/Public Industry']
# R^2: 0.06992477666071131
# Root Mean Square: 0.017709443027488437
# ['% Less than High School', '% High School Diploma', '% College Grad']
# R^2: 0.09505527608769597
# Root Mean Square: 0.03836049226458234
# ['% No English Speaking Adults in HH', '% English Spoken in HH', '% Spanish Spoken in HH', '% Chinese Spoken in HH', '% Korean Spoken in HH', '% Vietnamese Spoken in HH', '% Tagalog Spoken in HH', '% Russian Spoken in HH', '% Other Language Spoken in HH']
# R^2: 0.020399718666641118
# Root Mean Square: 0.02875167311486513

# %%
#finding the R^2 and rms between the married condition and
#other vairables
for col in new_cols:
    print(col)
    perform_linear(['% Married'],col)
# Out:
# ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL', '% HIU Income 400% FPL']
# R^2: 0.05390187190608649
# Root Mean Square: 0.04112159300906002
# ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
# R^2: 0.16704503915821217
# Root Mean Square: 0.029139557202815698
# ['% Male', '% Female']
# R^2: 0.3801451673393695
# Root Mean Square: 0.02710224369568119
# % Married
# R^2: 1.0
# Root Mean Square: 1.229037546096733e-17
# % Child in Family
# R^2: 0.15694576830100504
# Root Mean Square: 0.0557644510034097
# ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino', '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander', '% American Indian / Alaska Native', '% Multi-racial or Other']
# R^2: 0.12451227116145797
# Root Mean Square: 0.10092545167626601
# % SNAP Recipient
# R^2: 0.014158474560785783
# Root Mean Square: 0.04971458396980963
# % With a disability
# R^2: 0.002386862825068947
# Root Mean Square: 0.02240513416812255
# % Full-time Worker in Family
# R^2: 0.2524752820613668
# Root Mean Square: 0.041863573447943746
# ['% Employed in Agriculture Industry', '% Employed in Mining/Construction Industry', '% Employed in Manufacturing Industry', '% Employed in Trade Industry', '% Employed in Info/Finance Industry', '% Employed in Education/Health Industry', '% Employed in Entertainment Industry', '% Employed in Service Industry', '% Employed in Military/Public Industry']
# R^2: 0.12982098641297254
# Root Mean Square: 0.017391563485503185
# ['% Less than High School', '% High School Diploma', '% College Grad']
# R^2: 0.05975735239705112
# Root Mean Square: 0.03909153358296286
# ['% No English Speaking Adults in HH', '% English Spoken in HH', '% Spanish Spoken in HH', '% Chinese Spoken in HH', '% Korean Spoken in HH', '% Vietnamese Spoken in HH', '% Tagalog Spoken in HH', '% Russian Spoken in HH', '% Other Language Spoken in HH']
# R^2: 0.013137672718516723
# Root Mean Square: 0.02884923290175473

# %%
#finding the R^2 and rms between the child_in_Family condition and
#other vairables
for col in new_cols:
    print(col)
    perform_linear(['% Child in Family'],col)
# Out:
# ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL', '% HIU Income 400% FPL']
# R^2: 0.07652065569640545
# Root Mean Square: 0.041099609182615134
# ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
# R^2: 0.28985033888191114
# Root Mean Square: 0.025103268247437152
# ['% Male', '% Female']
# R^2: 0.4187009305067846
# Root Mean Square: 0.026245815052751257
# % Married
# R^2: 0.15694576830100482
# Root Mean Square: 0.031889120581485166
# % Child in Family
# R^2: 1.0
# Root Mean Square: 4.8074067159589095e-17
# ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino', '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander', '% American Indian / Alaska Native', '% Multi-racial or Other']
# R^2: 0.0518756359583698
# Root Mean Square: 0.10854822077305432
# % SNAP Recipient
# R^2: 0.013549889759129297
# Root Mean Square: 0.049729926634684285
# % With a disability
# R^2: 0.012793288282075377
# Root Mean Square: 0.022287970221017143
# % Full-time Worker in Family
# R^2: 0.2669873715690302
# Root Mean Square: 0.04145522209313662
# ['% Employed in Agriculture Industry', '% Employed in Mining/Construction Industry', '% Employed in Manufacturing Industry', '% Employed in Trade Industry', '% Employed in Info/Finance Industry', '% Employed in Education/Health Industry', '% Employed in Entertainment Industry', '% Employed in Service Industry', '% Employed in Military/Public Industry']
# R^2: 0.06034470459263162
# Root Mean Square: 0.017828889795605384
# ['% Less than High School', '% High School Diploma', '% College Grad']
# R^2: 0.047012208866254866
# Root Mean Square: 0.03942583275884468
# ['% No English Speaking Adults in HH', '% English Spoken in HH', '% Spanish Spoken in HH', '% Chinese Spoken in HH', '% Korean Spoken in HH', '% Vietnamese Spoken in HH', '% Tagalog Spoken in HH', '% Russian Spoken in HH', '% Other Language Spoken in HH']
# R^2: 0.008264450465268901
# Root Mean Square: 0.028963749982449893

# %%
#finding the R^2 and rms between the group of origin variables and
#other vairables
for col in new_cols :
    print(col)
    perform_linear(origin,col)
# Out:
# ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL', '% HIU Income 400% FPL']
# R^2: 0.2722983839390108
# Root Mean Square: 0.03495605143566238
# ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
# R^2: 0.33444953612624845
# Root Mean Square: 0.02600207487391985
# ['% Male', '% Female']
# R^2: 0.17332013537507784
# Root Mean Square: 0.03129888959121728
# % Married
# R^2: 0.6469177467156346
# Root Mean Square: 0.02063729304559775
# % Child in Family
# R^2: 0.3363374498884444
# Root Mean Square: 0.04947699677907675
# ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino', '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander', '% American Indian / Alaska Native', '% Multi-racial or Other']
# R^2: 1.0
# Root Mean Square: 9.681776059659017e-17
# % SNAP Recipient
# R^2: 0.15205941186723138
# Root Mean Square: 0.04610658620988621
# % With a disability
# R^2: 0.25244426751681504
# Root Mean Square: 0.019394931819054183
# % Full-time Worker in Family
# R^2: 0.6258765719027604
# Root Mean Square: 0.029616311573958592
# ['% Employed in Agriculture Industry', '% Employed in Mining/Construction Industry', '% Employed in Manufacturing Industry', '% Employed in Trade Industry', '% Employed in Info/Finance Industry', '% Employed in Education/Health Industry', '% Employed in Entertainment Industry', '% Employed in Service Industry', '% Employed in Military/Public Industry']
# R^2: 0.28895835017587135
# Root Mean Square: 0.015375172482220426
# ['% Less than High School', '% High School Diploma', '% College Grad']
# R^2: 0.33900648486332363
# Root Mean Square: 0.0332339529261471
# ['% No English Speaking Adults in HH', '% English Spoken in HH', '% Spanish Spoken in HH', '% Chinese Spoken in HH', '% Korean Spoken in HH', '% Vietnamese Spoken in HH', '% Tagalog Spoken in HH', '% Russian Spoken in HH', '% Other Language Spoken in HH']
# R^2: 0.4701751288065082
# Root Mean Square: 0.01414068290765033

# %%
#finding the R^2 and rms between the SNAP recipient condition and
#other vairables
for col in new_cols:
    print(col)
    perform_linear(['% SNAP Recipient'],col)
# Out:
# ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL', '% HIU Income 400% FPL']
# R^2: 0.25513289216807317
# Root Mean Square: 0.03383779453467455
# ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
# R^2: 0.04588723729852123
# Root Mean Square: 0.03094861422777898
# ['% Male', '% Female']
# R^2: 0.042012122134640395
# Root Mean Square: 0.03369304461912621
# % Married
# R^2: 0.014158474560785117
# Root Mean Square: 0.03448405587442394
# % Child in Family
# R^2: 0.013549889759129075
# Root Mean Square: 0.060320820107935845
# ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino', '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander', '% American Indian / Alaska Native', '% Multi-racial or Other']
# R^2: 0.027167777838703815
# Root Mean Square: 0.10916245320244872
# % SNAP Recipient
# R^2: 1.0
# Root Mean Square: 1.3179959344295418e-17
# % With a disability
# R^2: 0.22091751859927222
# Root Mean Square: 0.019799680786971988
# % Full-time Worker in Family
# R^2: 0.2952313647340191
# Root Mean Square: 0.04064871320169127
# ['% Employed in Agriculture Industry', '% Employed in Mining/Construction Industry', '% Employed in Manufacturing Industry', '% Employed in Trade Industry', '% Employed in Info/Finance Industry', '% Employed in Education/Health Industry', '% Employed in Entertainment Industry', '% Employed in Service Industry', '% Employed in Military/Public Industry']
# R^2: 0.01861148955357223
# Root Mean Square: 0.018232450406318348
# ['% Less than High School', '% High School Diploma', '% College Grad']
# R^2: 0.08544037201451575
# Root Mean Square: 0.03845359556384269
# ['% No English Speaking Adults in HH', '% English Spoken in HH', '% Spanish Spoken in HH', '% Chinese Spoken in HH', '% Korean Spoken in HH', '% Vietnamese Spoken in HH', '% Tagalog Spoken in HH', '% Russian Spoken in HH', '% Other Language Spoken in HH']
# R^2: 0.012936124648690971
# Root Mean Square: 0.028813666586294053

# %%
#finding the R^2 and rms between the disability condition and
#other vairables
for col in new_cols:
    print(col)
    perform_linear(['% With a disability'],col)
# Out:
# ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL', '% HIU Income 400% FPL']
# R^2: 0.18721147908634353
# Root Mean Square: 0.036872706110898275
# ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
# R^2: 0.01043593615443622
# Root Mean Square: 0.03167612039341446
# ['% Male', '% Female']
# R^2: 0.09202973580220697
# Root Mean Square: 0.03280167815922143
# % Married
# R^2: 0.002386862825068725
# Root Mean Square: 0.034689326351199236
# % Child in Family
# R^2: 0.01279328828207571
# Root Mean Square: 0.060343948532421796
# ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino', '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander', '% American Indian / Alaska Native', '% Multi-racial or Other']
# R^2: 0.06008014531601036
# Root Mean Square: 0.10701256970632594
# % SNAP Recipient
# R^2: 0.22091751859927256
# Root Mean Square: 0.044194881636665774
# % With a disability
# R^2: 1.0
# Root Mean Square: 1.605411917726113e-17
# % Full-time Worker in Family
# R^2: 0.110570812871565
# Root Mean Square: 0.04566455252523303
# ['% Employed in Agriculture Industry', '% Employed in Mining/Construction Industry', '% Employed in Manufacturing Industry', '% Employed in Trade Industry', '% Employed in Info/Finance Industry', '% Employed in Education/Health Industry', '% Employed in Entertainment Industry', '% Employed in Service Industry', '% Employed in Military/Public Industry']
# R^2: 0.040867180677760656
# Root Mean Square: 0.0178504514623781
# ['% Less than High School', '% High School Diploma', '% College Grad']
# R^2: 0.1281068313294412
# Root Mean Square: 0.037514739589879734
# ['% No English Speaking Adults in HH', '% English Spoken in HH', '% Spanish Spoken in HH', '% Chinese Spoken in HH', '% Korean Spoken in HH', '% Vietnamese Spoken in HH', '% Tagalog Spoken in HH', '% Russian Spoken in HH', '% Other Language Spoken in HH']
# R^2: 0.11606874490329694
# Root Mean Square: 0.02522776140684105

# %%
#finding the R^2 and rms between full time worker variables and
#other vairables
for col in new_cols :
    print(col)
    perform_linear(['% Full-time Worker in Family'],col)
# Out:
# ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL', '% HIU Income 400% FPL']
# R^2: 0.371660261379708
# Root Mean Square: 0.028681428202707214
# ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
# R^2: 0.09462181474167183
# Root Mean Square: 0.02981020544755352
# ['% Male', '% Female']
# R^2: 0.05949938286038092
# Root Mean Square: 0.033384109231041445
# % Married
# R^2: 0.2524752820613665
# Root Mean Square: 0.030028080071080192
# % Child in Family
# R^2: 0.2669873715690301
# Root Mean Square: 0.05199785193529589
# ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino', '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander', '% American Indian / Alaska Native', '% Multi-racial or Other']
# R^2: 0.13550122169656778
# Root Mean Square: 0.09917036745510552
# % SNAP Recipient
# R^2: 0.29523136473401923
# Root Mean Square: 0.04203427292810468
# % With a disability
# R^2: 0.1105708128715649
# Root Mean Square: 0.021155444638860498
# % Full-time Worker in Family
# R^2: 1.0
# Root Mean Square: 4.663869570635836e-17
# ['% Employed in Agriculture Industry', '% Employed in Mining/Construction Industry', '% Employed in Manufacturing Industry', '% Employed in Trade Industry', '% Employed in Info/Finance Industry', '% Employed in Education/Health Industry', '% Employed in Entertainment Industry', '% Employed in Service Industry', '% Employed in Military/Public Industry']
# R^2: 0.07131225216535285
# Root Mean Square: 0.017828195683575316
# ['% Less than High School', '% High School Diploma', '% College Grad']
# R^2: 0.07209052612637205
# Root Mean Square: 0.03892701072948289
# ['% No English Speaking Adults in HH', '% English Spoken in HH', '% Spanish Spoken in HH', '% Chinese Spoken in HH', '% Korean Spoken in HH', '% Vietnamese Spoken in HH', '% Tagalog Spoken in HH', '% Russian Spoken in HH', '% Other Language Spoken in HH']
# R^2: 0.008728033176880978
# Root Mean Square: 0.028962285259064132

# %%
#finding the R^2 and rms between the group of employment variables and
#other vairables
for col in new_cols :
    print(col)
    perform_linear(employment,col)
# Out:
# ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL', '% HIU Income 400% FPL']
# R^2: 0.39492044858085407
# Root Mean Square: 0.032952786115352524
# ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
# R^2: 0.44105957615689084
# Root Mean Square: 0.023408101185650534
# ['% Male', '% Female']
# R^2: 0.4178030087431288
# Root Mean Square: 0.02626607793982943
# % Married
# R^2: 0.6012804546184766
# Root Mean Square: 0.021930500792819368
# % Child in Family
# R^2: 0.5831252519405847
# Root Mean Square: 0.039213216668060664
# ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino', '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander', '% American Indian / Alaska Native', '% Multi-racial or Other']
# R^2: 0.39589636904040143
# Root Mean Square: 0.07999723491614447
# % SNAP Recipient
# R^2: 0.20975432302159935
# Root Mean Square: 0.04451038184817805
# % With a disability
# R^2: 0.3540643855185788
# Root Mean Square: 0.01802856186199141
# % Full-time Worker in Family
# R^2: 0.4102847507812172
# Root Mean Square: 0.03718302313985382
# ['% Employed in Agriculture Industry', '% Employed in Mining/Construction Industry', '% Employed in Manufacturing Industry', '% Employed in Trade Industry', '% Employed in Info/Finance Industry', '% Employed in Education/Health Industry', '% Employed in Entertainment Industry', '% Employed in Service Industry', '% Employed in Military/Public Industry']
# R^2: 1.0
# Root Mean Square: 2.386427253336896e-17
# ['% Less than High School', '% High School Diploma', '% College Grad']
# R^2: 0.5291002577296554
# Root Mean Square: 0.027266029732776902
# ['% No English Speaking Adults in HH', '% English Spoken in HH', '% Spanish Spoken in HH', '% Chinese Spoken in HH', '% Korean Spoken in HH', '% Vietnamese Spoken in HH', '% Tagalog Spoken in HH', '% Russian Spoken in HH', '% Other Language Spoken in HH']
# R^2: 0.28522433372138806
# Root Mean Square: 0.022831725127739916

# %%
#finding the R^2 and rms between the group of education variables and
#other vairables
for col in new_cols :
    print(col)
    perform_linear(education,col)
# Out:
# ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL', '% HIU Income 400% FPL']
# R^2: 0.32543903716053446
# Root Mean Square: 0.03467237460430579
# ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
# R^2: 0.12538943929158733
# Root Mean Square: 0.029818700647882782
# ['% Male', '% Female']
# R^2: 0.19875765895826947
# Root Mean Square: 0.030813582637487562
# % Married
# R^2: 0.1315470880323566
# Root Mean Square: 0.032365917607312285
# % Child in Family
# R^2: 0.10541714563939464
# Root Mean Square: 0.057443376510222625
# ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino', '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander', '% American Indian / Alaska Native', '% Multi-racial or Other']
# R^2: 0.2096599303132711
# Root Mean Square: 0.09857410218341571
# % SNAP Recipient
# R^2: 0.15822736238835333
# Root Mean Square: 0.04593858966081443
# % With a disability
# R^2: 0.26467379339217156
# Root Mean Square: 0.019235633388823482
# % Full-time Worker in Family
# R^2: 0.15606437573431042
# Root Mean Square: 0.04448137234233661
# ['% Employed in Agriculture Industry', '% Employed in Mining/Construction Industry', '% Employed in Manufacturing Industry', '% Employed in Trade Industry', '% Employed in Info/Finance Industry', '% Employed in Education/Health Industry', '% Employed in Entertainment Industry', '% Employed in Service Industry', '% Employed in Military/Public Industry']
# R^2: 0.18849088073425938
# Root Mean Square: 0.016195600714230294
# ['% Less than High School', '% High School Diploma', '% College Grad']
# R^2: 1.0
# Root Mean Square: 4.1131463437146705e-17
# ['% No English Speaking Adults in HH', '% English Spoken in HH', '% Spanish Spoken in HH', '% Chinese Spoken in HH', '% Korean Spoken in HH', '% Vietnamese Spoken in HH', '% Tagalog Spoken in HH', '% Russian Spoken in HH', '% Other Language Spoken in HH']
# R^2: 0.24293270634290298
# Root Mean Square: 0.02190016822863573

# %%
#finding the R^2 and rms between the group of spoken language variables and
#other vairables
for col in new_cols :
    print(col)
    perform_linear(language,col)
# Out:
# ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL', '% HIU Income 400% FPL']
# R^2: 0.2410715053227371
# Root Mean Square: 0.036900218378628176
# ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
# R^2: 0.17390460516188452
# Root Mean Square: 0.029092560253964478
# ['% Male', '% Female']
# R^2: 0.26928874514639767
# Root Mean Square: 0.029426129953228058
# % Married
# R^2: 0.14662607660239746
# Root Mean Square: 0.03208370173987188
# % Child in Family
# R^2: 0.1548561955598753
# Root Mean Square: 0.05583351640776113
# ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino', '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander', '% American Indian / Alaska Native', '% Multi-racial or Other']
# R^2: 0.5019633424285824
# Root Mean Square: 0.08113159821355982
# % SNAP Recipient
# R^2: 0.11353442502743305
# Root Mean Square: 0.04714234622644926
# % With a disability
# R^2: 0.3915161480364254
# Root Mean Square: 0.017498104176971317
# % Full-time Worker in Family
# R^2: 0.11272699692015042
# Root Mean Square: 0.04560916816927179
# ['% Employed in Agriculture Industry', '% Employed in Mining/Construction Industry', '% Employed in Manufacturing Industry', '% Employed in Trade Industry', '% Employed in Info/Finance Industry', '% Employed in Education/Health Industry', '% Employed in Entertainment Industry', '% Employed in Service Industry', '% Employed in Military/Public Industry']
# R^2: 0.22139167591599132
# Root Mean Square: 0.016066002306915583
# ['% Less than High School', '% High School Diploma', '% College Grad']
# R^2: 0.3946303976422021
# Root Mean Square: 0.031614564607243614
# ['% No English Speaking Adults in HH', '% English Spoken in HH', '% Spanish Spoken in HH', '% Chinese Spoken in HH', '% Korean Spoken in HH', '% Vietnamese Spoken in HH', '% Tagalog Spoken in HH', '% Russian Spoken in HH', '% Other Language Spoken in HH']
# R^2: 1.0
# Root Mean Square: 2.9031987654382273e-17

# %%
# re-define vairable groups to separate individual variables as columns
income_new = [['% HIU Income < 100% FPL'], ['% HIU Income 100-138% FPL'],
          ['% HIU Income 139-249% FPL'], ['% HIU Income 250-400% FPL'],
          ['% HIU Income 400% FPL']]
age_new = [['% Age 0-18'], ['% Age 19-34'], ['% Age 35-49'], ['% Age 50-64']]
gender_new = [['% Male'], ['% Female']]
origin_new = [['% Spanish/Hispanic/Latino Origin'], ['% White Non-Latino'],
          ['% Black Non-Latino'], ['% Asian / Native-Hawaiian / Pac Islander'],
          ['% American Indian / Alaska Native'], ['% Multi-racial or Other']]
employment_new = [['% Employed in Agriculture Industry'], 
             ['% Employed in Mining/Construction Industry'],['% Employed in Manufacturing Industry'], 
             ['% Employed in Trade Industry'],['% Employed in Info/Finance Industry'], 
             ['% Employed in Education/Health Industry'],['% Employed in Entertainment Industry'],
             ['% Employed in Service Industry'],['% Employed in Military/Public Industry']]
education_new = [['% Less than High School'], ['% High School Diploma'], ['% College Grad']]
language_new = [['% No English Speaking Adults in HH'], ['% English Spoken in HH'],
            ['% Spanish Spoken in HH'], ['% Chinese Spoken in HH'],
            ['% Korean Spoken in HH'], ['% Vietnamese Spoken in HH'],
            ['% Tagalog Spoken in HH'], ['% Russian Spoken in HH'],
            ['% Other Language Spoken in HH']]

# %%
# finding the R^2 and rms between variables in group of income
for col1 in income_new:
    for col2 in income_new:
        print(col1)
        print(col2)
        perform_linear(col1,col2)
# Out:
# ['% HIU Income < 100% FPL']
# ['% HIU Income < 100% FPL']
# R^2: 1.0
# Root Mean Square: 4.310401311189063e-17
# ['% HIU Income < 100% FPL']
# ['% HIU Income 100-138% FPL']
# R^2: 0.1569844970174067
# Root Mean Square: 0.01650601721205957
# ['% HIU Income < 100% FPL']
# ['% HIU Income 139-249% FPL']
# R^2: 0.21123250185779807
# Root Mean Square: 0.024916352974247123
# ['% HIU Income < 100% FPL']
# ['% HIU Income 250-400% FPL']
# R^2: 0.7425387656518447
# Root Mean Square: 0.01675360357620652
# ['% HIU Income < 100% FPL']
# ['% HIU Income 400% FPL']
# R^2: 0.477235093134902
# Root Mean Square: 0.03393775305794642
# ['% HIU Income 100-138% FPL']
# ['% HIU Income < 100% FPL']
# R^2: 0.15698449701740647
# Root Mean Square: 0.06182018359100534
# ['% HIU Income 100-138% FPL']
# ['% HIU Income 100-138% FPL']
# R^2: 1.0
# Root Mean Square: 0.0
# ['% HIU Income 100-138% FPL']
# ['% HIU Income 139-249% FPL']
# R^2: 0.00031007966177865054
# Root Mean Square: 0.028050630525670864
# ['% HIU Income 100-138% FPL']
# ['% HIU Income 250-400% FPL']
# R^2: 0.13444725367697485
# Root Mean Square: 0.0307184346232025
# ['% HIU Income 100-138% FPL']
# ['% HIU Income 400% FPL']
# R^2: 0.4700760430795764
# Root Mean Square: 0.034169344640276295
# ['% HIU Income 139-249% FPL']
# ['% HIU Income < 100% FPL']
# R^2: 0.21123250185779796
# Root Mean Square: 0.059798048793535355
# ['% HIU Income 139-249% FPL']
# ['% HIU Income 100-138% FPL']
# R^2: 0.00031007966177831747
# Root Mean Square: 0.017974514536212797
# ['% HIU Income 139-249% FPL']
# ['% HIU Income 139-249% FPL']
# R^2: 1.0
# Root Mean Square: 1.0282865859286678e-17
# ['% HIU Income 139-249% FPL']
# ['% HIU Income 250-400% FPL']
# R^2: 0.08409618537449137
# Root Mean Square: 0.03159928422983557
# ['% HIU Income 139-249% FPL']
# ['% HIU Income 400% FPL']
# R^2: 0.018693377176869808
# Root Mean Square: 0.04649778203539806
# ['% HIU Income 250-400% FPL']
# ['% HIU Income < 100% FPL']
# R^2: 0.7425387656518447
# Root Mean Square: 0.0341639779852464
# ['% HIU Income 250-400% FPL']
# ['% HIU Income 100-138% FPL']
# R^2: 0.1344472536769752
# Root Mean Square: 0.01672519855802367
# ['% HIU Income 250-400% FPL']
# ['% HIU Income 139-249% FPL']
# R^2: 0.08409618537449137
# Root Mean Square: 0.026849419789140405
# ['% HIU Income 250-400% FPL']
# ['% HIU Income 250-400% FPL']
# R^2: 1.0
# Root Mean Square: 1.7810446115699925e-17
# ['% HIU Income 250-400% FPL']
# ['% HIU Income 400% FPL']
# R^2: 0.22870667535143463
# Root Mean Square: 0.04122300611246496
# ['% HIU Income 400% FPL']
# ['% HIU Income < 100% FPL']
# R^2: 0.47723509313490187
# Root Mean Square: 0.04868169854184524
# ['% HIU Income 400% FPL']
# ['% HIU Income 100-138% FPL']
# R^2: 0.4700760430795766
# Root Mean Square: 0.013086734443932484
# ['% HIU Income 400% FPL']
# ['% HIU Income 139-249% FPL']
# R^2: 0.018693377176869697
# Root Mean Square: 0.027791522296945485
# ['% HIU Income 400% FPL']
# ['% HIU Income 250-400% FPL']
# R^2: 0.22870667535143463
# Root Mean Square: 0.028997602868076663
# ['% HIU Income 400% FPL']
# ['% HIU Income 400% FPL']
# R^2: 1.0
# Root Mean Square: 3.15745462550488e-17

# %%
# finding the R^2 and rms between variables in group of age
for col1 in age_new:
    for col2 in age_new:
        print(col1)
        print(col2)
        perform_linear(col1,col2)
# Out:
# ['% Age 0-18']
# ['% Age 0-18']
# R^2: 1.0
# Root Mean Square: 2.784048121504467e-17
# ['% Age 0-18']
# ['% Age 19-34']
# R^2: 0.1585044315516384
# Root Mean Square: 0.03156683762422529
# ['% Age 0-18']
# ['% Age 35-49']
# R^2: 0.3655470897643246
# Root Mean Square: 0.018392318144082875
# ['% Age 0-18']
# ['% Age 50-64']
# R^2: 0.19570920365387878
# Root Mean Square: 0.024504091442670302
# ['% Age 19-34']
# ['% Age 0-18']
# R^2: 0.1585044315516384
# Root Mean Square: 0.03654480034840237
# ['% Age 19-34']
# ['% Age 19-34']
# R^2: 1.0
# Root Mean Square: 3.2978537999661915e-17
# ['% Age 19-34']
# ['% Age 35-49']
# R^2: 0.058787464908530485
# Root Mean Square: 0.02240168184318884
# ['% Age 19-34']
# ['% Age 50-64']
# R^2: 0.22347845487698925
# Root Mean Square: 0.02407735687782516
# ['% Age 35-49']
# ['% Age 0-18']
# R^2: 0.36554708976432493
# Root Mean Square: 0.03173214089201162
# ['% Age 35-49']
# ['% Age 19-34']
# R^2: 0.05878746490853071
# Root Mean Square: 0.03338481784400975
# ['% Age 35-49']
# ['% Age 35-49']
# R^2: 1.0
# Root Mean Square: 0.0
# ['% Age 35-49']
# ['% Age 50-64']
# R^2: 0.11479716865954648
# Root Mean Square: 0.025707121616841588
# ['% Age 50-64']
# ['% Age 0-18']
# R^2: 0.1957092036538789
# Root Mean Square: 0.03572779604221855
# ['% Age 50-64']
# ['% Age 19-34']
# R^2: 0.2234784548769897
# Root Mean Square: 0.030323680681624016
# ['% Age 50-64']
# ['% Age 35-49']
# R^2: 0.11479716865954637
# Root Mean Square: 0.021724919249301467
# ['% Age 50-64']
# ['% Age 50-64']
# R^2: 1.0
# Root Mean Square: 0.0

# %%
# finding the R^2 and rms between variables in group of origin
for col1 in origin_new:
    for col2 in origin_new:
        print(col1)
        print(col2)
        perform_linear(col1,col2)
# Out:
# ['% Spanish/Hispanic/Latino Origin']
# ['% Spanish/Hispanic/Latino Origin']
# R^2: 1.0
# Root Mean Square: 8.527762723407564e-17
# ['% Spanish/Hispanic/Latino Origin']
# ['% White Non-Latino']
# R^2: 0.40652726028985364
# Root Mean Square: 0.13254201869404725
# ['% Spanish/Hispanic/Latino Origin']
# ['% Black Non-Latino']
# R^2: 0.03818246898676536
# Root Mean Square: 0.13086172077109884
# ['% Spanish/Hispanic/Latino Origin']
# ['% Asian / Native-Hawaiian / Pac Islander']
# R^2: 0.020696281251902038
# Root Mean Square: 0.0635019883316531
# ['% Spanish/Hispanic/Latino Origin']
# ['% American Indian / Alaska Native']
# R^2: 0.0006159549993384195
# Root Mean Square: 0.07189347363577639
# ['% Spanish/Hispanic/Latino Origin']
# ['% Multi-racial or Other']
# R^2: 0.012277494894090024
# Root Mean Square: 0.02605885542575207
# ['% White Non-Latino']
# ['% Spanish/Hispanic/Latino Origin']
# R^2: 0.40652726028985375
# Root Mean Square: 0.1015579300160963
# ['% White Non-Latino']
# ['% White Non-Latino']
# R^2: 1.0
# Root Mean Square: 4.7441486082078665e-17
# ['% White Non-Latino']
# ['% Black Non-Latino']
# R^2: 0.1357665688123303
# Root Mean Square: 0.12404572836100584
# ['% White Non-Latino']
# ['% Asian / Native-Hawaiian / Pac Islander']
# R^2: 0.1675889201085491
# Root Mean Square: 0.0585460431046888
# ['% White Non-Latino']
# ['% American Indian / Alaska Native']
# R^2: 0.010182740190140871
# Root Mean Square: 0.0715485395009124
# ['% White Non-Latino']
# ['% Multi-racial or Other']
# R^2: 0.06825583632762944
# Root Mean Square: 0.025309653665055123
# ['% Black Non-Latino']
# ['% Spanish/Hispanic/Latino Origin']
# R^2: 0.03818246898676514
# Root Mean Square: 0.1292884703368099
# ['% Black Non-Latino']
# ['% White Non-Latino']
# R^2: 0.13576656881233018
# Root Mean Square: 0.15994428410219044
# ['% Black Non-Latino']
# ['% Black Non-Latino']
# R^2: 1.0
# Root Mean Square: 2.1880773445923968e-17
# ['% Black Non-Latino']
# ['% Asian / Native-Hawaiian / Pac Islander']
# R^2: 0.02445466043692801
# Root Mean Square: 0.0633800169890584
# ['% Black Non-Latino']
# ['% American Indian / Alaska Native']
# R^2: 0.13488875173406167
# Root Mean Square: 0.06688969893177592
# ['% Black Non-Latino']
# ['% Multi-racial or Other']
# R^2: 0.05397119769473735
# Root Mean Square: 0.02550292779314291
# ['% Asian / Native-Hawaiian / Pac Islander']
# ['% Spanish/Hispanic/Latino Origin']
# R^2: 0.02069628125190237
# Root Mean Square: 0.13045843209175828
# ['% Asian / Native-Hawaiian / Pac Islander']
# ['% White Non-Latino']
# R^2: 0.1675889201085493
# Root Mean Square: 0.1569719738938396
# ['% Asian / Native-Hawaiian / Pac Islander']
# ['% Black Non-Latino']
# R^2: 0.024454660436928233
# Root Mean Square: 0.13179229225065736
# ['% Asian / Native-Hawaiian / Pac Islander']
# ['% Asian / Native-Hawaiian / Pac Islander']
# R^2: 1.0
# Root Mean Square: 1.0148662883750261e-16
# ['% Asian / Native-Hawaiian / Pac Islander']
# ['% American Indian / Alaska Native']
# R^2: 0.018540961638018882
# Root Mean Square: 0.07124581375129187
# ['% Asian / Native-Hawaiian / Pac Islander']
# ['% Multi-racial or Other']
# R^2: 0.45710665423160457
# Root Mean Square: 0.01931946613223454
# ['% American Indian / Alaska Native']
# ['% Spanish/Hispanic/Latino Origin']
# R^2: 0.0006159549993386415
# Root Mean Square: 0.13178915053704574
# ['% American Indian / Alaska Native']
# ['% White Non-Latino']
# R^2: 0.010182740190140649
# Root Mean Square: 0.1711712036530415
# ['% American Indian / Alaska Native']
# ['% Black Non-Latino']
# R^2: 0.1348887517340619
# Root Mean Square: 0.12410871008487376
# ['% American Indian / Alaska Native']
# ['% Asian / Native-Hawaiian / Pac Islander']
# R^2: 0.01854096163801877
# Root Mean Square: 0.0635718297171527
# ['% American Indian / Alaska Native']
# ['% American Indian / Alaska Native']
# R^2: 1.0
# Root Mean Square: 7.96951720093542e-17
# ['% American Indian / Alaska Native']
# ['% Multi-racial or Other']
# R^2: 0.08243767323650164
# Root Mean Square: 0.025116299248590237
# ['% Multi-racial or Other']
# ['% Spanish/Hispanic/Latino Origin']
# R^2: 0.012277494894089691
# Root Mean Square: 0.13101798848627444
# ['% Multi-racial or Other']
# ['% White Non-Latino']
# R^2: 0.06825583632762922
# Root Mean Square: 0.16607395709880826
# ['% Multi-racial or Other']
# ['% Black Non-Latino']
# R^2: 0.05397119769473768
# Root Mean Square: 0.12978319514321085
# ['% Multi-racial or Other']
# ['% Asian / Native-Hawaiian / Pac Islander']
# R^2: 0.45710665423160446
# Root Mean Square: 0.04728091594483709
# ['% Multi-racial or Other']
# ['% American Indian / Alaska Native']
# R^2: 0.08243767323650142
# Root Mean Square: 0.06888759910355337
# ['% Multi-racial or Other']
# ['% Multi-racial or Other']
# R^2: 1.0
# Root Mean Square: 1.2628977532625829e-17

# %%
# finding the R^2 and rms between variables in group of origin
for col1 in employment_new:
    for col2 in employment_new:
        print(col1)
        print(col2)
        perform_linear(col1,col2)
# Out:
# ['% Employed in Agriculture Industry']
# ['% Employed in Agriculture Industry']
# R^2: 1.0
# Root Mean Square: 3.383343034060412e-18
# ['% Employed in Agriculture Industry']
# ['% Employed in Mining/Construction Industry']
# R^2: 0.14369309914313155
# Root Mean Square: 0.015878234248331492
# ['% Employed in Agriculture Industry']
# ['% Employed in Manufacturing Industry']
# R^2: 0.05209324421203276
# Root Mean Square: 0.02562512107100393
# ['% Employed in Agriculture Industry']
# ['% Employed in Trade Industry']
# R^2: 0.08013976839263337
# Root Mean Square: 0.019538083148022533
# ['% Employed in Agriculture Industry']
# ['% Employed in Info/Finance Industry']
# R^2: 0.08908539414462846
# Root Mean Square: 0.021487814567928826
# ['% Employed in Agriculture Industry']
# ['% Employed in Education/Health Industry']
# R^2: 0.04215389970473615
# Root Mean Square: 0.01690474099536352
# ['% Employed in Agriculture Industry']
# ['% Employed in Entertainment Industry']
# R^2: 0.03603316497328357
# Root Mean Square: 0.018899675606970527
# ['% Employed in Agriculture Industry']
# ['% Employed in Service Industry']
# R^2: 0.0015894949391871416
# Root Mean Square: 0.007683561631355743
# ['% Employed in Agriculture Industry']
# ['% Employed in Military/Public Industry']
# R^2: 0.05468539498021274
# Root Mean Square: 0.014158920285055563
# ['% Employed in Mining/Construction Industry']
# ['% Employed in Agriculture Industry']
# R^2: 0.14369309914313144
# Root Mean Square: 0.012881303445257822
# ['% Employed in Mining/Construction Industry']
# ['% Employed in Mining/Construction Industry']
# R^2: 1.0
# Root Mean Square: 9.716394938824659e-18
# ['% Employed in Mining/Construction Industry']
# ['% Employed in Manufacturing Industry']
# R^2: 5.113706950832242e-05
# Root Mean Square: 0.026319159266901912
# ['% Employed in Mining/Construction Industry']
# ['% Employed in Trade Industry']
# R^2: 0.019758950330356906
# Root Mean Square: 0.02016914436702533
# ['% Employed in Mining/Construction Industry']
# ['% Employed in Info/Finance Industry']
# R^2: 0.10871273075600119
# Root Mean Square: 0.021255056626170884
# ['% Employed in Mining/Construction Industry']
# ['% Employed in Education/Health Industry']
# R^2: 0.0024684323113252082
# Root Mean Square: 0.01725138539999337
# ['% Employed in Mining/Construction Industry']
# ['% Employed in Entertainment Industry']
# R^2: 0.09307473568681424
# Root Mean Square: 0.01833196645857672
# ['% Employed in Mining/Construction Industry']
# ['% Employed in Service Industry']
# R^2: 0.0004904051940932685
# Root Mean Square: 0.007687789652246909
# ['% Employed in Mining/Construction Industry']
# ['% Employed in Military/Public Industry']
# R^2: 0.21791721210496406
# Root Mean Square: 0.012878589985179859
# ['% Employed in Manufacturing Industry']
# ['% Employed in Agriculture Industry']
# R^2: 0.052093244212032874
# Root Mean Square: 0.013552764701606598
# ['% Employed in Manufacturing Industry']
# ['% Employed in Mining/Construction Industry']
# R^2: 5.1137069508544464e-05
# Root Mean Square: 0.01715838380981579
# ['% Employed in Manufacturing Industry']
# ['% Employed in Manufacturing Industry']
# R^2: 1.0
# Root Mean Square: 0.0
# ['% Employed in Manufacturing Industry']
# ['% Employed in Trade Industry']
# R^2: 0.03359174055330283
# Root Mean Square: 0.02002632907703707
# ['% Employed in Manufacturing Industry']
# ['% Employed in Info/Finance Industry']
# R^2: 0.021596468975307093
# Root Mean Square: 0.02226960020154093
# ['% Employed in Manufacturing Industry']
# ['% Employed in Education/Health Industry']
# R^2: 0.024983335467286927
# Root Mean Square: 0.017055587064190855
# ['% Employed in Manufacturing Industry']
# ['% Employed in Entertainment Industry']
# R^2: 0.007326980745753553
# Root Mean Square: 0.01917902003419978
# ['% Employed in Manufacturing Industry']
# ['% Employed in Service Industry']
# R^2: 0.09226437345002514
# Root Mean Square: 0.007326350613654942
# ['% Employed in Manufacturing Industry']
# ['% Employed in Military/Public Industry']
# R^2: 0.24803196792621207
# Root Mean Square: 0.012628205536679144
# ['% Employed in Trade Industry']
# ['% Employed in Agriculture Industry']
# R^2: 0.08013976839263337
# Root Mean Square: 0.013350760672384486
# ['% Employed in Trade Industry']
# ['% Employed in Mining/Construction Industry']
# R^2: 0.019758950330356795
# Root Mean Square: 0.016988456618577945
# ['% Employed in Trade Industry']
# ['% Employed in Manufacturing Industry']
# R^2: 0.03359174055330261
# Root Mean Square: 0.02587399162407668
# ['% Employed in Trade Industry']
# ['% Employed in Trade Industry']
# R^2: 1.0
# Root Mean Square: 3.3658579400898804e-18
# ['% Employed in Trade Industry']
# ['% Employed in Info/Finance Industry']
# R^2: 0.0037037667866657298
# Root Mean Square: 0.02247230697938239
# ['% Employed in Trade Industry']
# ['% Employed in Education/Health Industry']
# R^2: 0.004427816437396537
# Root Mean Square: 0.017234434204203737
# ['% Employed in Trade Industry']
# ['% Employed in Entertainment Industry']
# R^2: 0.05209505955466187
# Root Mean Square: 0.018741558256683777
# ['% Employed in Trade Industry']
# ['% Employed in Service Industry']
# R^2: 0.062302169185463385
# Root Mean Square: 0.007446281733098749
# ['% Employed in Trade Industry']
# ['% Employed in Military/Public Industry']
# R^2: 0.08823128185107831
# Root Mean Square: 0.013905425952627254
# ['% Employed in Info/Finance Industry']
# ['% Employed in Agriculture Industry']
# R^2: 0.08908539414462857
# Root Mean Square: 0.013285684103783316
# ['% Employed in Info/Finance Industry']
# ['% Employed in Mining/Construction Industry']
# R^2: 0.1087127307560013
# Root Mean Square: 0.016199303209976115
# ['% Employed in Info/Finance Industry']
# ['% Employed in Manufacturing Industry']
# R^2: 0.021596468975307093
# Root Mean Square: 0.026034073247433155
# ['% Employed in Info/Finance Industry']
# ['% Employed in Trade Industry']
# R^2: 0.0037037667866655077
# Root Mean Square: 0.020333646822692515
# ['% Employed in Info/Finance Industry']
# ['% Employed in Info/Finance Industry']
# R^2: 1.0
# Root Mean Square: 2.2745497394595518e-17
# ['% Employed in Info/Finance Industry']
# ['% Employed in Education/Health Industry']
# R^2: 0.005439616607274322
# Root Mean Square: 0.0172256742988413
# ['% Employed in Info/Finance Industry']
# ['% Employed in Entertainment Industry']
# R^2: 0.022158994189305115
# Root Mean Square: 0.019035199225317052
# ['% Employed in Info/Finance Industry']
# ['% Employed in Service Industry']
# R^2: 0.059999490940764844
# Root Mean Square: 0.007455418939571249
# ['% Employed in Info/Finance Industry']
# ['% Employed in Military/Public Industry']
# R^2: 0.04288547116931041
# Root Mean Square: 0.014247015841410283
# ['% Employed in Education/Health Industry']
# ['% Employed in Agriculture Industry']
# R^2: 0.04215389970473582
# Root Mean Square: 0.013623633655506997
# ['% Employed in Education/Health Industry']
# ['% Employed in Mining/Construction Industry']
# R^2: 0.0024684323113250972
# Root Mean Square: 0.017137631760300424
# ['% Employed in Education/Health Industry']
# ['% Employed in Manufacturing Industry']
# R^2: 0.024983335467286927
# Root Mean Square: 0.025988974080182563
# ['% Employed in Education/Health Industry']
# ['% Employed in Trade Industry']
# R^2: 0.004427816437396426
# Root Mean Square: 0.020326256829015642
# ['% Employed in Education/Health Industry']
# ['% Employed in Info/Finance Industry']
# R^2: 0.0054396166072741
# Root Mean Square: 0.02245272166191688
# ['% Employed in Education/Health Industry']
# ['% Employed in Education/Health Industry']
# R^2: 1.0
# Root Mean Square: 8.244634499915479e-18
# ['% Employed in Education/Health Industry']
# ['% Employed in Entertainment Industry']
# R^2: 0.025870548364979817
# Root Mean Square: 0.018999039286567793
# ['% Employed in Education/Health Industry']
# ['% Employed in Service Industry']
# R^2: 0.005795532195646547
# Root Mean Square: 0.007667360151957922
# ['% Employed in Education/Health Industry']
# ['% Employed in Military/Public Industry']
# R^2: 0.05411821428320407
# Root Mean Square: 0.014163167263792565
# ['% Employed in Entertainment Industry']
# ['% Employed in Agriculture Industry']
# R^2: 0.03603316497328335
# Root Mean Square: 0.01366709254690939
# ['% Employed in Entertainment Industry']
# ['% Employed in Mining/Construction Industry']
# R^2: 0.09307473568681401
# Root Mean Square: 0.016340796925913535
# ['% Employed in Entertainment Industry']
# ['% Employed in Manufacturing Industry']
# R^2: 0.007326980745753442
# Root Mean Square: 0.02622323251165046
# ['% Employed in Entertainment Industry']
# ['% Employed in Trade Industry']
# R^2: 0.05209505955466209
# Root Mean Square: 0.019833685627949453
# ['% Employed in Entertainment Industry']
# ['% Employed in Info/Finance Industry']
# R^2: 0.022158994189305004
# Root Mean Square: 0.022263197417646378
# ['% Employed in Entertainment Industry']
# ['% Employed in Education/Health Industry']
# R^2: 0.025870548364979706
# Root Mean Square: 0.017047825463158008
# ['% Employed in Entertainment Industry']
# ['% Employed in Entertainment Industry']
# R^2: 1.0
# Root Mean Square: 9.114786389946357e-18
# ['% Employed in Entertainment Industry']
# ['% Employed in Service Industry']
# R^2: 1.3222885820396435e-05
# Root Mean Square: 0.007689624571835223
# ['% Employed in Entertainment Industry']
# ['% Employed in Military/Public Industry']
# R^2: 0.04037049009203897
# Root Mean Square: 0.014265721788844114
# ['% Employed in Service Industry']
# ['% Employed in Agriculture Industry']
# R^2: 0.0015894949391872526
# Root Mean Square: 0.013909120193233811
# ['% Employed in Service Industry']
# ['% Employed in Mining/Construction Industry']
# R^2: 0.0004904051940934906
# Root Mean Square: 0.01715461463756807
# ['% Employed in Service Industry']
# ['% Employed in Manufacturing Industry']
# R^2: 0.09226437345002514
# Root Mean Square: 0.025076262484281558
# ['% Employed in Service Industry']
# ['% Employed in Trade Industry']
# R^2: 0.062302169185463274
# Root Mean Square: 0.019726611314054857
# ['% Employed in Service Industry']
# ['% Employed in Info/Finance Industry']
# R^2: 0.059999490940765066
# Root Mean Square: 0.021828176615135687
# ['% Employed in Service Industry']
# ['% Employed in Education/Health Industry']
# R^2: 0.005795532195646547
# Root Mean Square: 0.01722259181400335
# ['% Employed in Service Industry']
# ['% Employed in Entertainment Industry']
# R^2: 1.3222885820507457e-05
# Root Mean Square: 0.019249543400744827
# ['% Employed in Service Industry']
# ['% Employed in Service Industry']
# R^2: 1.0
# Root Mean Square: 0.0
# ['% Employed in Service Industry']
# ['% Employed in Military/Public Industry']
# R^2: 0.12456772927373727
# Root Mean Square: 0.013625524491579834
# ['% Employed in Military/Public Industry']
# ['% Employed in Agriculture Industry']
# R^2: 0.05468539498021252
# Root Mean Square: 0.013534221285106828
# ['% Employed in Military/Public Industry']
# ['% Employed in Mining/Construction Industry']
# R^2: 0.21791721210496418
# Root Mean Square: 0.015174481019422658
# ['% Employed in Military/Public Industry']
# ['% Employed in Manufacturing Industry']
# R^2: 0.2480319679262123
# Root Mean Square: 0.0228235294935524
# ['% Employed in Military/Public Industry']
# ['% Employed in Trade Industry']
# R^2: 0.08823128185107831
# Root Mean Square: 0.019451960355233396
# ['% Employed in Military/Public Industry']
# ['% Employed in Info/Finance Industry']
# R^2: 0.04288547116931052
# Root Mean Square: 0.022025986518562295
# ['% Employed in Military/Public Industry']
# ['% Employed in Education/Health Industry']
# R^2: 0.05411821428320418
# Root Mean Square: 0.016798831917312605
# ['% Employed in Military/Public Industry']
# ['% Employed in Entertainment Industry']
# R^2: 0.04037049009203941
# Root Mean Square: 0.018857108553616712
# ['% Employed in Military/Public Industry']
# ['% Employed in Service Industry']
# R^2: 0.12456772927373738
# Root Mean Square: 0.007194809246545523
# ['% Employed in Military/Public Industry']
# ['% Employed in Military/Public Industry']
# R^2: 1.0
# Root Mean Square: 3.3331802165905475e-17

# %%
# finding the R^2 and rms between variables in group of education
for col1 in education_new:
    for col2 in education_new:
        print(col1)
        print(col2)
        perform_linear(col1,col2)
# Out:
# ['% Less than High School']
# ['% Less than High School']
# R^2: 1.0
# Root Mean Square: 6.445127265397921e-18
# ['% Less than High School']
# ['% High School Diploma']
# R^2: 0.11146564019475358
# Root Mean Square: 0.03528514189045454
# ['% Less than High School']
# ['% College Grad']
# R^2: 0.3612563154186226
# Root Mean Square: 0.03504533742503137
# ['% High School Diploma']
# ['% Less than High School']
# R^2: 0.11146564019475369
# Root Mean Square: 0.037210538840139265
# ['% High School Diploma']
# ['% High School Diploma']
# R^2: 1.0
# Root Mean Square: 0.0
# ['% High School Diploma']
# ['% College Grad']
# R^2: 0.2972043256455723
# Root Mean Square: 0.036760505611764145
# ['% College Grad']
# ['% Less than High School']
# R^2: 0.3612563154186228
# Root Mean Square: 0.03154947634402731
# ['% College Grad']
# ['% High School Diploma']
# R^2: 0.2972043256455722
# Root Mean Square: 0.031381181788180564
# ['% College Grad']
# ['% College Grad']
# R^2: 1.0
# Root Mean Square: 3.958760270690572e-17

# %%
# finding the R^2 and rms between variables in group of language
for col1 in language_new:
    for col2 in language_new:
        print(col1)
        print(col2)
        perform_linear(col1,col2)
# Out:
# ['% No English Speaking Adults in HH']
# ['% No English Speaking Adults in HH']
# R^2: 1.0
# Root Mean Square: 2.608992264607233e-17
# ['% No English Speaking Adults in HH']
# ['% English Spoken in HH']
# R^2: 0.9382110471589412
# Root Mean Square: 0.01481727178959659
# ['% No English Speaking Adults in HH']
# ['% Spanish Spoken in HH']
# R^2: 0.847161959385834
# Root Mean Square: 0.01805990758291089
# ['% No English Speaking Adults in HH']
# ['% Chinese Spoken in HH']
# R^2: 0.1855667365120549
# Root Mean Square: 0.005146864646606655
# ['% No English Speaking Adults in HH']
# ['% Korean Spoken in HH']
# R^2: 0.22425866956883744
# Root Mean Square: 0.002072380635640463
# ['% No English Speaking Adults in HH']
# ['% Vietnamese Spoken in HH']
# R^2: 0.028820710782052616
# Root Mean Square: 0.0023187865169133712
# ['% No English Speaking Adults in HH']
# ['% Tagalog Spoken in HH']
# R^2: 0.002202815624005927
# Root Mean Square: 0.0013849559276427716
# ['% No English Speaking Adults in HH']
# ['% Russian Spoken in HH']
# R^2: 0.14315744567374855
# Root Mean Square: 0.0012834097372531844
# ['% No English Speaking Adults in HH']
# ['% Other Language Spoken in HH']
# R^2: 0.27584433545231035
# Root Mean Square: 0.016199794320223202
# ['% English Spoken in HH']
# ['% No English Speaking Adults in HH']
# R^2: 0.9382110471589412
# Root Mean Square: 0.009546068403415852
# ['% English Spoken in HH']
# ['% English Spoken in HH']
# R^2: 1.0
# Root Mean Square: 5.1561018123183366e-17
# ['% English Spoken in HH']
# ['% Spanish Spoken in HH']
# R^2: 0.8585115209818451
# Root Mean Square: 0.01737642106687676
# ['% English Spoken in HH']
# ['% Chinese Spoken in HH']
# R^2: 0.23968388396397888
# Root Mean Square: 0.004972927111143666
# ['% English Spoken in HH']
# ['% Korean Spoken in HH']
# R^2: 0.284841600188806
# Root Mean Square: 0.0019898126257579113
# ['% English Spoken in HH']
# ['% Vietnamese Spoken in HH']
# R^2: 0.05766069274433505
# Root Mean Square: 0.002284097895877175
# ['% English Spoken in HH']
# ['% Tagalog Spoken in HH']
# R^2: 0.004181134823430632
# Root Mean Square: 0.0013835822795826912
# ['% English Spoken in HH']
# ['% Russian Spoken in HH']
# R^2: 0.13919152605733398
# Root Mean Square: 0.0012863764571787958
# ['% English Spoken in HH']
# ['% Other Language Spoken in HH']
# R^2: 0.325491175084906
# Root Mean Square: 0.015634620805631938
# ['% Spanish Spoken in HH']
# ['% No English Speaking Adults in HH']
# R^2: 0.847161959385834
# Root Mean Square: 0.015013600489674076
# ['% Spanish Spoken in HH']
# ['% English Spoken in HH']
# R^2: 0.858511520981845
# Root Mean Square: 0.02242194942020368
# ['% Spanish Spoken in HH']
# ['% Spanish Spoken in HH']
# R^2: 1.0
# Root Mean Square: 1.969668077593365e-17
# ['% Spanish Spoken in HH']
# ['% Chinese Spoken in HH']
# R^2: 0.10157690310646705
# Root Mean Square: 0.005405743688060392
# ['% Spanish Spoken in HH']
# ['% Korean Spoken in HH']
# R^2: 0.2692513000779525
# Root Mean Square: 0.002011384439127835
# ['% Spanish Spoken in HH']
# ['% Vietnamese Spoken in HH']
# R^2: 0.06165549212027244
# Root Mean Square: 0.0022792513381814333
# ['% Spanish Spoken in HH']
# ['% Tagalog Spoken in HH']
# R^2: 0.018241270904677198
# Root Mean Square: 0.0013737800398393452
# ['% Spanish Spoken in HH']
# ['% Russian Spoken in HH']
# R^2: 0.06912550026661479
# Root Mean Square: 0.0013377051008326322
# ['% Spanish Spoken in HH']
# ['% Other Language Spoken in HH']
# R^2: 0.06434104246279115
# Root Mean Square: 0.0184141774652171
# ['% Chinese Spoken in HH']
# ['% No English Speaking Adults in HH']
# R^2: 0.18556673651205502
# Root Mean Square: 0.03465747159542006
# ['% Chinese Spoken in HH']
# ['% English Spoken in HH']
# R^2: 0.23968388396397888
# Root Mean Square: 0.05197684659796179
# ['% Chinese Spoken in HH']
# ['% Spanish Spoken in HH']
# R^2: 0.10157690310646694
# Root Mean Square: 0.04378650152109014
# ['% Chinese Spoken in HH']
# ['% Chinese Spoken in HH']
# R^2: 1.0
# Root Mean Square: 1.2266347333466993e-18
# ['% Chinese Spoken in HH']
# ['% Korean Spoken in HH']
# R^2: 0.0266696217494099
# Root Mean Square: 0.0023213530653306874
# ['% Chinese Spoken in HH']
# ['% Vietnamese Spoken in HH']
# R^2: 0.026669621749409678
# Root Mean Square: 0.002321353065330688
# ['% Chinese Spoken in HH']
# ['% Tagalog Spoken in HH']
# R^2: 0.030638297872340625
# Root Mean Square: 0.001365078872565013
# ['% Chinese Spoken in HH']
# ['% Russian Spoken in HH']
# R^2: 0.45021276595744697
# Root Mean Square: 0.0010280450399295258
# ['% Chinese Spoken in HH']
# ['% Other Language Spoken in HH']
# R^2: 0.159558672105102
# Root Mean Square: 0.017452081587334686
# ['% Korean Spoken in HH']
# ['% No English Speaking Adults in HH']
# R^2: 0.22425866956883722
# Root Mean Square: 0.0338242043777229
# ['% Korean Spoken in HH']
# ['% English Spoken in HH']
# R^2: 0.28484160018880567
# Root Mean Square: 0.05040968127369788
# ['% Korean Spoken in HH']
# ['% Spanish Spoken in HH']
# R^2: 0.2692513000779523
# Root Mean Square: 0.039489698557116
# ['% Korean Spoken in HH']
# ['% Chinese Spoken in HH']
# R^2: 0.0266696217494089
# Root Mean Square: 0.005626588248377615
# ['% Korean Spoken in HH']
# ['% Korean Spoken in HH']
# R^2: 1.0
# Root Mean Square: 1.734723475976807e-18
# ['% Korean Spoken in HH']
# ['% Vietnamese Spoken in HH']
# R^2: 0.41710069444444464
# Root Mean Square: 0.0017964197835536226
# ['% Korean Spoken in HH']
# ['% Tagalog Spoken in HH']
# R^2: 0.0012500000000008615
# Root Mean Square: 0.0013856170303136106
# ['% Korean Spoken in HH']
# ['% Russian Spoken in HH']
# R^2: 0.0012500000000006395
# Root Mean Square: 0.0013856170303136106
# ['% Korean Spoken in HH']
# ['% Other Language Spoken in HH']
# R^2: 0.02801426838981147
# Root Mean Square: 0.018768237016102977
# ['% Vietnamese Spoken in HH']
# ['% No English Speaking Adults in HH']
# R^2: 0.02882071078205206
# Root Mean Square: 0.03784589940068958
# ['% Vietnamese Spoken in HH']
# ['% English Spoken in HH']
# R^2: 0.05766069274433505
# Root Mean Square: 0.057865070026498475
# ['% Vietnamese Spoken in HH']
# ['% Spanish Spoken in HH']
# R^2: 0.06165549212027188
# Root Mean Square: 0.044748754405058634
# ['% Vietnamese Spoken in HH']
# ['% Chinese Spoken in HH']
# R^2: 0.026669621749409123
# Root Mean Square: 0.005626588248377614
# ['% Vietnamese Spoken in HH']
# ['% Korean Spoken in HH']
# R^2: 0.41710069444444464
# Root Mean Square: 0.0017964197835536226
# ['% Vietnamese Spoken in HH']
# ['% Vietnamese Spoken in HH']
# R^2: 1.0
# Root Mean Square: 3.4454477225427066e-18
# ['% Vietnamese Spoken in HH']
# ['% Tagalog Spoken in HH']
# R^2: 0.0012500000000008615
# Root Mean Square: 0.0013856170303136106
# ['% Vietnamese Spoken in HH']
# ['% Russian Spoken in HH']
# R^2: 0.0012500000000005285
# Root Mean Square: 0.0013856170303136108
# ['% Vietnamese Spoken in HH']
# ['% Other Language Spoken in HH']
# R^2: 0.0026522385566423168
# Root Mean Square: 0.01901152010229986
# ['% Tagalog Spoken in HH']
# ['% No English Speaking Adults in HH']
# R^2: 0.002202815624005372
# Root Mean Square: 0.03836103017420744
# ['% Tagalog Spoken in HH']
# ['% English Spoken in HH']
# R^2: 0.004181134823430077
# Root Mean Square: 0.0594843888943896
# ['% Tagalog Spoken in HH']
# ['% Spanish Spoken in HH']
# R^2: 0.018241270904676754
# Root Mean Square: 0.04577224128142731
# ['% Tagalog Spoken in HH']
# ['% Chinese Spoken in HH']
# R^2: 0.030638297872340403
# Root Mean Square: 0.005615105551566361
# ['% Tagalog Spoken in HH']
# ['% Korean Spoken in HH']
# R^2: 0.0012500000000006395
# Root Mean Square: 0.0023514700758295684
# ['% Tagalog Spoken in HH']
# ['% Vietnamese Spoken in HH']
# R^2: 0.0012500000000006395
# Root Mean Square: 0.0023514700758295684
# ['% Tagalog Spoken in HH']
# ['% Tagalog Spoken in HH']
# R^2: 1.0
# Root Mean Square: 3.4348785570068733e-18
# ['% Tagalog Spoken in HH']
# ['% Russian Spoken in HH']
# R^2: 0.000400000000000289
# Root Mean Square: 0.001386206529183213
# ['% Tagalog Spoken in HH']
# ['% Other Language Spoken in HH']
# R^2: 0.19479948798158386
# Root Mean Square: 0.017082268965050402
# ['% Russian Spoken in HH']
# ['% No English Speaking Adults in HH']
# R^2: 0.14315744567374866
# Root Mean Square: 0.03554836560065608
# ['% Russian Spoken in HH']
# ['% English Spoken in HH']
# R^2: 0.13919152605733365
# Root Mean Square: 0.0553052164461733
# ['% Russian Spoken in HH']
# ['% Spanish Spoken in HH']
# R^2: 0.06912550026661446
# Root Mean Square: 0.04457027971222214
# ['% Russian Spoken in HH']
# ['% Chinese Spoken in HH']
# R^2: 0.45021276595744686
# Root Mean Square: 0.004228753024447397
# ['% Russian Spoken in HH']
# ['% Korean Spoken in HH']
# R^2: 0.0012500000000006395
# Root Mean Square: 0.0023514700758295684
# ['% Russian Spoken in HH']
# ['% Vietnamese Spoken in HH']
# R^2: 0.0012500000000008615
# Root Mean Square: 0.002351470075829568
# ['% Russian Spoken in HH']
# ['% Tagalog Spoken in HH']
# R^2: 0.00040000000000040004
# Root Mean Square: 0.001386206529183213
# ['% Russian Spoken in HH']
# ['% Russian Spoken in HH']
# R^2: 1.0
# Root Mean Square: 1.9617240031188413e-18
# ['% Russian Spoken in HH']
# ['% Other Language Spoken in HH']
# R^2: 0.04774029805075053
# Root Mean Square: 0.018576814204269505
# ['% Other Language Spoken in HH']
# ['% No English Speaking Adults in HH']
# R^2: 0.27584433545231024
# Root Mean Square: 0.03268022895927934
# ['% Other Language Spoken in HH']
# ['% English Spoken in HH']
# R^2: 0.32549117508490566
# Root Mean Square: 0.0489560813305568
# ['% Other Language Spoken in HH']
# ['% Spanish Spoken in HH']
# R^2: 0.06434104246279104
# Root Mean Square: 0.044684672854796596
# ['% Other Language Spoken in HH']
# ['% Chinese Spoken in HH']
# R^2: 0.159558672105102
# Root Mean Square: 0.005228398674132208
# ['% Other Language Spoken in HH']
# ['% Korean Spoken in HH']
# R^2: 0.028014268389811803
# Root Mean Square: 0.0023197490475883546
# ['% Other Language Spoken in HH']
# ['% Vietnamese Spoken in HH']
# R^2: 0.002652238556643205
# Root Mean Square: 0.0023498187716127984
# ['% Other Language Spoken in HH']
# ['% Tagalog Spoken in HH']
# R^2: 0.19479948798158409
# Root Mean Square: 0.0012441330798523248
# ['% Other Language Spoken in HH']
# ['% Russian Spoken in HH']
# R^2: 0.04774029805075086
# Root Mean Square: 0.0013529835595662652
# ['% Other Language Spoken in HH']
# ['% Other Language Spoken in HH']
# R^2: 1.0
# Root Mean Square: 8.539931814369215e-18

# %% [markdown]
# ## Run Linear Regression Between Every Potential Variable and the Uninsured Percentage as a Reference for Dropping Variables

# %%
# define a function to perform linear regression between given columns of data
# uninsured percentage
def perform_linear(cols):
    x = states[cols]
    y = states[['Percent Uninsured']]
    lr = LinearRegression()
    reg = lr.fit(x, y)
    y_pred = lr.predict(x)
    
    r2 = reg.score(x, y)
    rms = np.sqrt(mean_squared_error(y, y_pred))
    print('R^2:', r2)
    print('Root Mean Square:', rms)

# %%
states.columns
# Out:
# Index(['State Name', 'Total Non-Elderly Population (Excluding Undocumented)',
#        'Uninsured Population (Excluding Undocumented)', 'Percent Uninsured',
#        '% HIU Income < 100% FPL', '% HIU Income 100-138% FPL',
#        '% HIU Income 139-249% FPL', '% HIU Income 250-400% FPL',
#        '% HIU Income 400% FPL', '% Age 0-18', '% Age 19-34', '% Age 35-49',
#        '% Age 50-64', '% Male', '% Female', '% Married', '% Child in Family',
#        '% Spanish/Hispanic/Latino Origin', '% White Non-Latino',
#        '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander',
#        '% American Indian / Alaska Native', '% Multi-racial or Other',
#        '% SNAP Recipient', '% With a disability',
#        '% Full-time Worker in Family', '% Employed in Agriculture Industry',
#        '% Employed in Mining/Construction Industry',
#        '% Employed in Manufacturing Industry', '% Employed in Trade Industry',
#        '% Employed in Info/Finance Industry',
#        '% Employed in Education/Health Industry',
#        '% Employed in Entertainment Industry',
#        '% Employed in Service Industry',
#        '% Employed in Military/Public Industry', '% Less than High School',
#        '% High School Diploma', '% College Grad',
#        '% No English Speaking Adults in HH', '% English Spoken in HH',
#        '% Spanish Spoken in HH', '% Chinese Spoken in HH',
#        '% Korean Spoken in HH', '% Vietnamese Spoken in HH',
#        '% Tagalog Spoken in HH', '% Russian Spoken in HH',
#        '% Other Language Spoken in HH'],
#       dtype='object')

# %%
# find the correlation factor between the income group and uninsured percentage
perform_linear(['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL', '% HIU Income 139-249% FPL', 
                 '% HIU Income 250-400% FPL', '% HIU Income 400% FPL'])
# Out:
# R^2: 0.4221985104899899
# Root Mean Square: 0.027262717077655534

# %%
# find the correlation factor between the age group and uninsured percentage
perform_linear(['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64'])
# Out:
# R^2: 0.20333064378569965
# Root Mean Square: 0.032012446399370634

# %%
# find the correlation factor between the gender group and uninsured percentage
perform_linear(['% Male', '% Female'])
# Out:
# R^2: 0.36443606826636854
# Root Mean Square: 0.02859298060064303

# %%
# find the correlation factor between the marriage status and uninsured percentage
perform_linear(['% Married'])
# Out:
# R^2: 0.048810559182319024
# Root Mean Square: 0.03497947753023497

# %%
# find the correlation factor between the pencentage of having child and uninsured percentage
perform_linear(['% Child in Family'])
# Out:
# R^2: 0.1466018640784159
# Root Mean Square: 0.03313261034754693

# %%
# find the correlation factor between the ethnicity group and uninsured percentage
perform_linear(['% Spanish/Hispanic/Latino Origin', '% White Non-Latino',
       '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander',
       '% American Indian / Alaska Native', '% Multi-racial or Other'])
# Out:
# R^2: 0.16940226706339923
# Root Mean Square: 0.0326870087134815

# %%
# find the correlation factor between the pencentage of having full time worker in family and uninsured percentage
perform_linear(['% Full-time Worker in Family'])
# Out:
# R^2: 0.0421275294009793
# Root Mean Square: 0.035102144846991

# %%
# find the correlation factor between the Employment group and uninsured percentage
perform_linear(['% Employed in Agriculture Industry',
       '% Employed in Mining/Construction Industry',
       '% Employed in Manufacturing Industry', '% Employed in Trade Industry',
       '% Employed in Info/Finance Industry',
       '% Employed in Education/Health Industry',
       '% Employed in Entertainment Industry',
       '% Employed in Service Industry',
       '% Employed in Military/Public Industry'])
# Out:
# R^2: 0.5391225253083505
# Root Mean Square: 0.02434851894530684

# %%
# find the correlation factor between the education group and uninsured percentage
perform_linear(['% Less than High School',
       '% High School Diploma', '% College Grad'])
# Out:
# R^2: 0.3829031600071472
# Root Mean Square: 0.02817451633504088

# %%
# find the correlation factor between the language spoken group and uninsured percentage
perform_linear(['% No English Speaking Adults in HH', '% English Spoken in HH',
       '% Spanish Spoken in HH', '% Chinese Spoken in HH',
       '% Korean Spoken in HH', '% Vietnamese Spoken in HH',
       '% Tagalog Spoken in HH', '% Russian Spoken in HH',
       '% Other Language Spoken in HH'])
# Out:
# R^2: 0.48412591314096665
# Root Mean Square: 0.025760344382349424

# %%
# finding the R^2 and rms between variables in group of income and uninsured percentage
for col1 in income_new:
    print(col1)
    perform_linear(col1)
# Out:
# ['% HIU Income < 100% FPL']
# R^2: 0.20604379560063324
# Root Mean Square: 0.03195788882100485
# ['% HIU Income 100-138% FPL']
# R^2: 0.2296670146886267
# Root Mean Square: 0.031478864297498015
# ['% HIU Income 139-249% FPL']
# R^2: 0.016659372874680556
# Root Mean Square: 0.03556573591409746
# ['% HIU Income 250-400% FPL']
# R^2: 0.14376937319444383
# Root Mean Square: 0.03318754957804502
# ['% HIU Income 400% FPL']
# R^2: 0.40067513390574194
# Root Mean Square: 0.02776584894420926

# %%
# finding the R^2 and rms between variables in group of age and uninsured percentage
for col1 in age_new:
    print(col1)
    perform_linear(col1)
# Out:
# ['% Age 0-18']
# R^2: 0.025007581634850395
# Root Mean Square: 0.03541444396380867
# ['% Age 19-34']
# R^2: 0.07617578106720646
# Root Mean Square: 0.034472634906504415
# ['% Age 35-49']
# R^2: 0.037135734605451276
# Root Mean Square: 0.03519349051990882
# ['% Age 50-64']
# R^2: 0.008880584036934036
# Root Mean Square: 0.03570613150223387

# %%
# finding the R^2 and rms between variables in group of origin and uninsured percentage
for col1 in origin_new:
    print(col1)
    perform_linear(col1)
# Out:
# ['% Spanish/Hispanic/Latino Origin']
# R^2: 0.007680848836102205
# Root Mean Square: 0.035727735834839694
# ['% White Non-Latino']
# R^2: 0.00406657514322728
# Root Mean Square: 0.0357927413567434
# ['% Black Non-Latino']
# R^2: 0.0005099745304933956
# Root Mean Square: 0.03585659453895806
# ['% Asian / Native-Hawaiian / Pac Islander']
# R^2: 0.08771440360134886
# Root Mean Square: 0.0342566757639419
# ['% American Indian / Alaska Native']
# R^2: 0.06237377386318921
# Root Mean Square: 0.034729192164349686
# ['% Multi-racial or Other']
# R^2: 0.00940401407410818
# Root Mean Square: 0.035696701695044845

# %%
# finding the R^2 and rms between variables in group of employment and uninsured percentage
for col1 in employment_new:
    print(col1)
    perform_linear(col1)
# Out:
# ['% Employed in Agriculture Industry']
# R^2: 0.0008473308311959249
# Root Mean Square: 0.03585054271819083
# ['% Employed in Mining/Construction Industry']
# R^2: 0.08731865636197067
# Root Mean Square: 0.03426410518899779
# ['% Employed in Manufacturing Industry']
# R^2: 0.012038949630173712
# Root Mean Square: 0.03564919436565927
# ['% Employed in Trade Industry']
# R^2: 0.03092646476493588
# Root Mean Square: 0.03530678515233211
# ['% Employed in Info/Finance Industry']
# R^2: 0.24614344952145473
# Root Mean Square: 0.031140398404683894
# ['% Employed in Education/Health Industry']
# R^2: 0.16393293019668498
# Root Mean Square: 0.03279445117169201
# ['% Employed in Entertainment Industry']
# R^2: 0.030868231481453345
# Root Mean Square: 0.03530784595890004
# ['% Employed in Service Industry']
# R^2: 0.0007773266742802099
# Root Mean Square: 0.03585179860387155
# ['% Employed in Military/Public Industry']
# R^2: 0.019375764743367996
# Root Mean Square: 0.03551657833585378

# %%
# finding the R^2 and rms between variables in group of education and uninsured percentage
for col1 in education_new:
    print(col1)
    perform_linear(col1)
# Out:
# ['% Less than High School']
# R^2: 0.07186415405549973
# Root Mean Square: 0.034552985757336216
# ['% High School Diploma']
# R^2: 0.19006744683928445
# Root Mean Square: 0.032277822977180654
# ['% College Grad']
# R^2: 0.3603637066937655
# Root Mean Square: 0.02868443877001768

# %%
# finding the R^2 and rms between variables in group of language and uninsured percentage
for col1 in language_new:
    print(col1)
    perform_linear(col1)
# Out:
# ['% No English Speaking Adults in HH']
# R^2: 0.015077499325028332
# Root Mean Square: 0.03559433123872854
# ['% English Spoken in HH']
# R^2: 0.052885802790135106
# Root Mean Square: 0.034904464657921616
# ['% Spanish Spoken in HH']
# R^2: 6.280687325999068e-06
# Root Mean Square: 0.03586562838151135
# ['% Chinese Spoken in HH']
# R^2: 0.16944075846677276
# Root Mean Square: 0.03268625131711238
# ['% Korean Spoken in HH']
# R^2: 0.031085615270357803
# Root Mean Square: 0.035303885824664136
# ['% Vietnamese Spoken in HH']
# R^2: 0.011364994468412104
# Root Mean Square: 0.035661351657948204
# ['% Tagalog Spoken in HH']
# R^2: 0.027375215853498114
# Root Mean Square: 0.035371418288289026
# ['% Russian Spoken in HH']
# R^2: 0.027375215853498114
# Root Mean Square: 0.035371418288289026
# ['% Other Language Spoken in HH']
# R^2: 0.26010058182825735
# Root Mean Square: 0.030850780159040886

# %% [markdown]
# # New Model after Removing Colinear Variables

# %%
# define a function to calculate the linear regression coefficients
def get_coef_from_linear(cols):
    x = states[cols]
    y = states[['Percent Uninsured']]
    lr = LinearRegression()
    reg = lr.fit(x, y)
    y_pred = lr.predict(x)

    r2 = reg.score(x, y)
    rms = np.sqrt(mean_squared_error(y, y_pred))
    print('R^2:', r2)
    print('Root Mean Square:', rms)
    
    print('Intercept:', reg.intercept_)
    
    df = pd.DataFrame(data=[[cols[i], reg.coef_[0][i]] for i in range(len(reg.coef_[0]))])
    return df

# %%
# re-define groups after removing colinear variables
income_removed = ['% HIU Income < 100% FPL', '% HIU Income 100-138% FPL',
           '% HIU Income 139-249% FPL', '% HIU Income 400% FPL']
age_removed = ['% Age 0-18', '% Age 19-34', '% Age 35-49', '% Age 50-64']
gender_removed = ['% Female']
origin_removed = ['% Spanish/Hispanic/Latino Origin', '% White Non-Latino',
          '% Black Non-Latino', '% Asian / Native-Hawaiian / Pac Islander',
          '% American Indian / Alaska Native', '% Multi-racial or Other']
employment_removed = ['% Employed in Agriculture Industry', 
             '% Employed in Mining/Construction Industry','% Employed in Manufacturing Industry', 
             '% Employed in Trade Industry','% Employed in Info/Finance Industry', 
             '% Employed in Education/Health Industry','% Employed in Entertainment Industry',
             '% Employed in Service Industry','% Employed in Military/Public Industry']
education_removed = ['% Less than High School', '% High School Diploma', '% College Grad']
language_removed = ['% English Spoken in HH',
            '% Spanish Spoken in HH', '% Chinese Spoken in HH',
            '% Korean Spoken in HH', '% Vietnamese Spoken in HH',
            '% Tagalog Spoken in HH', '% Russian Spoken in HH',
            '% Other Language Spoken in HH']
new_cols_removed = [income, age, gender, '% Married', origin,
          '% SNAP Recipient', '% With a disability', employment, education, 
            language]

# %%
# group all the significant variables
all_cols = [income_removed, age_removed, gender_removed, ['% Married'], origin_removed,
          ['% SNAP Recipient'], ['% With a disability'], employment_removed, education_removed, 
            language_removed]
all_cols = [item for sublist in all_cols for item in sublist]
all_cols
# Out:
# ['% HIU Income < 100% FPL',
#  '% HIU Income 100-138% FPL',
#  '% HIU Income 139-249% FPL',
#  '% HIU Income 400% FPL',
#  '% Age 0-18',
#  '% Age 19-34',
#  '% Age 35-49',
#  '% Age 50-64',
#  '% Female',
#  '% Married',
#  '% Spanish/Hispanic/Latino Origin',
#  '% White Non-Latino',
#  '% Black Non-Latino',
#  '% Asian / Native-Hawaiian / Pac Islander',
#  '% American Indian / Alaska Native',
#  '% Multi-racial or Other',
#  '% SNAP Recipient',
#  '% With a disability',
#  '% Employed in Agriculture Industry',
#  '% Employed in Mining/Construction Industry',
#  '% Employed in Manufacturing Industry',
#  '% Employed in Trade Industry',
#  '% Employed in Info/Finance Industry',
#  '% Employed in Education/Health Industry',
#  '% Employed in Entertainment Industry',
#  '% Employed in Service Industry',
#  '% Employed in Military/Public Industry',
#  '% Less than High School',
#  '% High School Diploma',
#  '% College Grad',
#  '% English Spoken in HH',
#  '% Spanish Spoken in HH',
#  '% Chinese Spoken in HH',
#  '% Korean Spoken in HH',
#  '% Vietnamese Spoken in HH',
#  '% Tagalog Spoken in HH',
#  '% Russian Spoken in HH',
#  '% Other Language Spoken in HH']

# %%
# get the final multiple linear regression
final = get_coef_from_linear(all_cols)
final
# Out:
# R^2: 0.9648518258102219
# Root Mean Square: 0.006724054009023251
# Intercept: [1.07453501]
#                                              0          1
# 0                      % HIU Income < 100% FPL   0.210882
# 1                    % HIU Income 100-138% FPL   0.250354
# 2                    % HIU Income 139-249% FPL   0.115122
# 3                        % HIU Income 400% FPL   0.192168
# 4                                   % Age 0-18  -0.921744
# 5                                  % Age 19-34  -0.766777
# 6                                  % Age 35-49  -0.464330
# 7                                  % Age 50-64  -0.963077
# 8                                     % Female   0.794246
# 9                                    % Married  -0.883973
# 10            % Spanish/Hispanic/Latino Origin  -0.082167
# 11                          % White Non-Latino  -0.122269
# 12                          % Black Non-Latino  -0.118287
# 13    % Asian / Native-Hawaiian / Pac Islander  -1.306753
# 14           % American Indian / Alaska Native  -0.204316
# 15                     % Multi-racial or Other   0.369516
# 16                            % SNAP Recipient  -0.090123
# 17                         % With a disability  -0.661616
# 18          % Employed in Agriculture Industry   0.715123
# 19  % Employed in Mining/Construction Industry   0.007897
# 20        % Employed in Manufacturing Industry  -0.527606
# 21                % Employed in Trade Industry  -0.091093
# 22         % Employed in Info/Finance Industry  -0.324549
# 23     % Employed in Education/Health Industry  -0.301633
# 24        % Employed in Entertainment Industry   0.391947
# 25              % Employed in Service Industry   0.495136
# 26      % Employed in Military/Public Industry  -0.594941
# 27                     % Less than High School   0.839374
# 28                       % High School Diploma   1.142363
# 29                              % College Grad   0.576887
# 30                      % English Spoken in HH  -1.256223
# 31                      % Spanish Spoken in HH  -0.997329
# 32                      % Chinese Spoken in HH  -1.431204
# 33                       % Korean Spoken in HH   0.220333
# 34                   % Vietnamese Spoken in HH  -1.068546
# 35                      % Tagalog Spoken in HH  36.900886
# 36                      % Russian Spoken in HH   4.063591
# 37               % Other Language Spoken in HH  -0.779935

# %%
# print the coefficients
for n in range(len(final[1])):
    print(final[0][n], ':', final[1][n])
# Out:
# % HIU Income < 100% FPL : 0.21088199130521942
# % HIU Income 100-138% FPL : 0.2503542393392726
# % HIU Income 139-249% FPL : 0.11512221448955885
# % HIU Income 400% FPL : 0.19216815332913123
# % Age 0-18 : -0.9217438778016305
# % Age 19-34 : -0.7667765625190943
# % Age 35-49 : -0.46432986344149435
# % Age 50-64 : -0.9630773744648873
# % Female : 0.7942455539599091
# % Married : -0.8839733624034881
# % Spanish/Hispanic/Latino Origin : -0.08216709644578778
# % White Non-Latino : -0.12226879228565299
# % Black Non-Latino : -0.11828706174981518
# % Asian / Native-Hawaiian / Pac Islander : -1.3067528404648332
# % American Indian / Alaska Native : -0.20431598385302385
# % Multi-racial or Other : 0.36951554568128536
# % SNAP Recipient : -0.09012319197845818
# % With a disability : -0.6616162201245839
# % Employed in Agriculture Industry : 0.7151230268431186
# % Employed in Mining/Construction Industry : 0.007897007005530296
# % Employed in Manufacturing Industry : -0.5276062705491094
# % Employed in Trade Industry : -0.09109316716182471
# % Employed in Info/Finance Industry : -0.3245494149127694
# % Employed in Education/Health Industry : -0.3016325538897321
# % Employed in Entertainment Industry : 0.3919469016384048
# % Employed in Service Industry : 0.4951360567326899
# % Employed in Military/Public Industry : -0.5949412262319261
# % Less than High School : 0.8393735162849179
# % High School Diploma : 1.1423631479058711
# % College Grad : 0.576886973692163
# % English Spoken in HH : -1.2562227783670312
# % Spanish Spoken in HH : -0.997329108249977
# % Chinese Spoken in HH : -1.4312036864369853
# % Korean Spoken in HH : 0.22033309899453957
# % Vietnamese Spoken in HH : -1.0685459680898388
# % Tagalog Spoken in HH : 36.900885752475844
# % Russian Spoken in HH : 4.063591196637027
# % Other Language Spoken in HH : -0.7799353403950006

# %%
# calculate the lienar regression coefficients for visulization
get_coef_from_linear(income_removed)
# Out:
# R^2: 0.4217381755315335
# Root Mean Square: 0.027273575030872167
# Intercept: [-0.02001716]
#                            0         1
# 0    % HIU Income < 100% FPL  0.151392
# 1  % HIU Income 100-138% FPL  0.315114
# 2  % HIU Income 139-249% FPL  0.276208
# 3      % HIU Income 400% FPL -0.228329

# %%
# calculate the lienar regression coefficients for visulization
get_coef_from_linear(age_removed)
# Out:
# R^2: 0.20333064378569965
# Root Mean Square: 0.032012446399370634
# Intercept: [1.11330287]
#              0         1
# 0   % Age 0-18 -0.872310
# 1  % Age 19-34 -1.259339
# 2  % Age 35-49 -0.553394
# 3  % Age 50-64 -1.277682

# %%
# calculate the lienar regression coefficients for visulization
get_coef_from_linear(gender_removed)
# Out:
# R^2: 0.36398023810200564
# Root Mean Square: 0.028603232289183336
# Intercept: [-0.17462981]
#           0         1
# 0  % Female  0.628577

# %%
# calculate the lienar regression coefficients for visulization
get_coef_from_linear(origin_removed)
# Out:
# R^2: 0.16940226706339923
# Root Mean Square: 0.0326870087134815
# Intercept: [0.28952575]
#                                           0         1
# 0          % Spanish/Hispanic/Latino Origin -0.162950
# 1                        % White Non-Latino -0.214496
# 2                        % Black Non-Latino -0.181228
# 3  % Asian / Native-Hawaiian / Pac Islander -0.421414
# 4         % American Indian / Alaska Native -0.106829
# 5                   % Multi-racial or Other -0.023982

# %%
# calculate the lienar regression coefficients for visulization
get_coef_from_linear(employment_removed)
# Out:
# R^2: 0.5391225253083505
# Root Mean Square: 0.02434851894530684
# Intercept: [0.33103727]
#                                             0         1
# 0          % Employed in Agriculture Industry -0.351561
# 1  % Employed in Mining/Construction Industry  0.184810
# 2        % Employed in Manufacturing Industry -0.329209
# 3                % Employed in Trade Industry -0.210847
# 4         % Employed in Info/Finance Industry -0.906209
# 5     % Employed in Education/Health Industry -0.879803
# 6        % Employed in Entertainment Industry -0.087256
# 7              % Employed in Service Industry  0.299292
# 8      % Employed in Military/Public Industry -0.249750

# %%
# calculate the lienar regression coefficients for visulization 
get_coef_from_linear(education_removed)
# Out:
# R^2: 0.3829031600071472
# Root Mean Square: 0.02817451633504088
# Intercept: [-0.48389246]
#                          0         1
# 0  % Less than High School  0.542682
# 1    % High School Diploma  0.686892
# 2           % College Grad  0.122309
